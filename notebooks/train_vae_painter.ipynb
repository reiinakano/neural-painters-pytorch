# %% [markdown]
# <a href="https://colab.research.google.com/github/reiinakano/neural-painters-pytorch/blob/master/notebooks/train_vae_painter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Optionally connect to google drive for saving and loading

# %%
# !nvidia-smi
# Out:
# Fri Dec  6 14:18:29 2019
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.33.01    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
#from google.colab import drive
#drive.mount('/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /drive

# %% [markdown]
# # Download dataset
#
# Download episodes.
# If you want to use/generate your own brushstrokes, go to https://github.com/reiinakano/diff-painter/blob/master/notebooks/generate_stroke_examples.ipynb or put your data under the data/ folder.
#
# Otherwise, you can download pre-calculated brushstrokes from Kaggle. You will need to set your API credentials via https://github.com/Kaggle/kaggle-api#api-credentials

# %%
# !mkdir -p ~/.kaggle

# Make sure to upload your Kaggle key from somewhere. I saved mine in Drive
#!cp "/drive/My Drive/kaggle.json" ~/.kaggle/

# %%
# !kaggle datasets download reiinakano/mypaint_brushstrokes
# Out:
# Downloading mypaint_brushstrokes.zip to /content
# 100% 29.8G/29.9G [06:22<00:00, 104MB/s]
# 100% 29.9G/29.9G [06:22<00:00, 83.7MB/s]

# %%
# !unzip mypaint_brushstrokes.zip

# %%
# !mv strokes-dataset data

# %% [markdown]
# # Install MyPaint and other dependencies

# %%
# Install mypaint
# !apt-get update
# !apt install -y build-essential
# !apt install -y libjson-c-dev libgirepository1.0-dev libglib2.0-dev
# !apt install autotools-dev intltool gettext libtool
# !wget https://github.com/mypaint/libmypaint/archive/v2.0.0-alpha.1.tar.gz
# !tar -xvf v2.0.0-alpha.1.tar.gz
# !mv libmypaint-2.0.0-alpha.1 libmypaint
# !cd libmypaint &&  ./autogen.sh
# !cd libmypaint && ./configure && make install
# !wget https://github.com/mypaint/mypaint-brushes/archive/v2.0.1.tar.gz
# !tar -xvf v2.0.1.tar.gz
# !mv mypaint-brushes-2.0.1 mypaint-brushes
# !cd mypaint-brushes && ./autogen.sh && ./configure && make && make install
# !apt-get install -y \
git swig gettext g++ gir1.2-gtk-3.0 libgtk-3-dev \
libpng-dev liblcms2-dev libjson-c-dev python-gi-dev
# !apt-get install -y \
python3-setuptools python3-dev python3-numpy python3-gi-cairo

# !wget https://github.com/mypaint/mypaint/archive/v2.0.0-alpha.10.tar.gz
# !tar -xvf v2.0.0-alpha.10.tar.gz
# !mv mypaint-2.0.0-alpha.10 mypaint

# !cd mypaint && python setup.py build
# !cd mypaint && python setup.py managed_install --prefix=/content/local/
# !ldconfig
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ InRelease [3,626 B]
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:3 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Ign:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Get:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release [564 B]
# Get:7 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release.gpg [833 B]
# Get:8 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease [21.3 kB]
# Hit:9 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:12 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Packages [25.5 kB]
# Get:13 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic InRelease [15.4 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:15 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [19.2 kB]
# Get:16 http://security.ubuntu.com/ubuntu bionic-security/multiverse amd64 Packages [6,783 B]
# Get:17 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [760 kB]
# Get:18 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [794 kB]
# Get:19 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 Packages [34.2 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [1,056 kB]
# Get:21 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main Sources [1,741 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [1,321 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic-updates/multiverse amd64 Packages [10.5 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [32.7 kB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic-backports/universe amd64 Packages [4,244 B]
# Get:26 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 Packages [840 kB]
# Fetched 6,939 kB in 4s (1,697 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# build-essential is already the newest version (12.4ubuntu1).
# The following packages were automatically installed and are no longer required:
#   cuda-cufft-10-1 cuda-cufft-dev-10-1 cuda-curand-10-1 cuda-curand-dev-10-1
#   cuda-cusolver-10-1 cuda-cusolver-dev-10-1 cuda-cusparse-10-1
#   cuda-cusparse-dev-10-1 cuda-license-10-2 cuda-npp-10-1 cuda-npp-dev-10-1
#   cuda-nsight-10-1 cuda-nsight-compute-10-1 cuda-nsight-systems-10-1
#   cuda-nvgraph-10-1 cuda-nvgraph-dev-10-1 cuda-nvjpeg-10-1
#   cuda-nvjpeg-dev-10-1 cuda-nvrtc-10-1 cuda-nvrtc-dev-10-1 cuda-nvvp-10-1
#   libcublas10 libnvidia-common-430 nsight-compute-2019.5.0
#   nsight-systems-2019.5.2
# Use 'apt autoremove' to remove them.
# 0 upgraded, 0 newly installed, 0 to remove and 41 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libglib2.0-dev is already the newest version (2.56.4-0ubuntu0.18.04.4).
# libglib2.0-dev set to manually installed.
# The following packages were automatically installed and are no longer required:
#   cuda-cufft-10-1 cuda-cufft-dev-10-1 cuda-curand-10-1 cuda-curand-dev-10-1
#   cuda-cusolver-10-1 cuda-cusolver-dev-10-1 cuda-cusparse-10-1
#   cuda-cusparse-dev-10-1 cuda-license-10-2 cuda-npp-10-1 cuda-npp-dev-10-1
#   cuda-nsight-10-1 cuda-nsight-compute-10-1 cuda-nsight-systems-10-1
#   cuda-nvgraph-10-1 cuda-nvgraph-dev-10-1 cuda-nvjpeg-10-1
#   cuda-nvjpeg-dev-10-1 cuda-nvrtc-10-1 cuda-nvrtc-dev-10-1 cuda-nvvp-10-1
#   libcublas10 libnvidia-common-430 nsight-compute-2019.5.0
#   nsight-systems-2019.5.2
# Use 'apt autoremove' to remove them.
# The following additional packages will be installed:
#   gir1.2-freedesktop gobject-introspection libffi-dev python3-mako
#   python3-markupsafe
# Suggested packages:
#   libgirepository1.0-doc python3-beaker python-mako-doc
# The following NEW packages will be installed:
#   gir1.2-freedesktop gobject-introspection libffi-dev libgirepository1.0-dev
#   libjson-c-dev python3-mako python3-markupsafe
# 0 upgraded, 7 newly installed, 0 to remove and 41 not upgraded.
# Need to get 1,223 kB of archives.
# After this operation, 10.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 gir1.2-freedesktop amd64 1.56.1-1 [9,080 B]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-markupsafe amd64 1.0-1build1 [13.5 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-mako all 1.0.7+ds1-1 [59.3 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/main amd64 gobject-introspection amd64 1.56.1-1 [270 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/main amd64 libffi-dev amd64 3.2.1-8 [156 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgirepository1.0-dev amd64 1.56.1-1 [683 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/main amd64 libjson-c-dev amd64 0.12.1-1.3 [31.7 kB]
# Fetched 1,223 kB in 1s (926 kB/s)
# Selecting previously unselected package gir1.2-freedesktop:amd64.
# (Reading database ... 135718 files and directories currently installed.)
# Preparing to unpack .../0-gir1.2-freedesktop_1.56.1-1_amd64.deb ...
# Unpacking gir1.2-freedesktop:amd64 (1.56.1-1) ...
# Selecting previously unselected package python3-markupsafe.
# Preparing to unpack .../1-python3-markupsafe_1.0-1build1_amd64.deb ...
# Unpacking python3-markupsafe (1.0-1build1) ...
# Selecting previously unselected package python3-mako.
# Preparing to unpack .../2-python3-mako_1.0.7+ds1-1_all.deb ...
# Unpacking python3-mako (1.0.7+ds1-1) ...
# Selecting previously unselected package gobject-introspection.
# Preparing to unpack .../3-gobject-introspection_1.56.1-1_amd64.deb ...
# Unpacking gobject-introspection (1.56.1-1) ...
# Selecting previously unselected package libffi-dev:amd64.
# Preparing to unpack .../4-libffi-dev_3.2.1-8_amd64.deb ...
# Unpacking libffi-dev:amd64 (3.2.1-8) ...
# Selecting previously unselected package libgirepository1.0-dev:amd64.
# Preparing to unpack .../5-libgirepository1.0-dev_1.56.1-1_amd64.deb ...
# Unpacking libgirepository1.0-dev:amd64 (1.56.1-1) ...
# Selecting previously unselected package libjson-c-dev:amd64.
# Preparing to unpack .../6-libjson-c-dev_0.12.1-1.3_amd64.deb ...
# Unpacking libjson-c-dev:amd64 (0.12.1-1.3) ...
# Setting up gir1.2-freedesktop:amd64 (1.56.1-1) ...
# Setting up libffi-dev:amd64 (3.2.1-8) ...
# Setting up python3-markupsafe (1.0-1build1) ...
# Setting up libjson-c-dev:amd64 (0.12.1-1.3) ...
# Setting up python3-mako (1.0.7+ds1-1) ...
# Setting up gobject-introspection (1.56.1-1) ...
# Setting up libgirepository1.0-dev:amd64 (1.56.1-1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following packages were automatically installed and are no longer required:
#   cuda-cufft-10-1 cuda-cufft-dev-10-1 cuda-curand-10-1 cuda-curand-dev-10-1
#   cuda-cusolver-10-1 cuda-cusolver-dev-10-1 cuda-cusparse-10-1
#   cuda-cusparse-dev-10-1 cuda-license-10-2 cuda-npp-10-1 cuda-npp-dev-10-1
#   cuda-nsight-10-1 cuda-nsight-compute-10-1 cuda-nsight-systems-10-1
#   cuda-nvgraph-10-1 cuda-nvgraph-dev-10-1 cuda-nvjpeg-10-1
#   cuda-nvjpeg-dev-10-1 cuda-nvrtc-10-1 cuda-nvrtc-dev-10-1 cuda-nvvp-10-1
#   libcublas10 libnvidia-common-430 nsight-compute-2019.5.0
#   nsight-systems-2019.5.2
# Use 'apt autoremove' to remove them.
# The following additional packages will be installed:
#   autoconf automake file gettext-base libauthen-sasl-perl libdata-dump-perl
#   libencode-locale-perl libfile-listing-perl libfont-afm-perl
#   libhtml-form-perl libhtml-format-perl libhtml-parser-perl
#   libhtml-tagset-perl libhtml-tree-perl libhttp-cookies-perl
#   libhttp-daemon-perl libhttp-date-perl libhttp-message-perl
#   libhttp-negotiate-perl libio-html-perl libio-socket-ssl-perl
#   liblwp-mediatypes-perl liblwp-protocol-https-perl libmagic-mgc libmagic1
#   libmailtools-perl libnet-http-perl libnet-smtp-ssl-perl libnet-ssleay-perl
#   libsigsegv2 libtimedate-perl libtry-tiny-perl liburi-perl libwww-perl
#   libwww-robotrules-perl libxml-parser-perl m4 netbase perl-openssl-defaults
# Suggested packages:
#   autoconf-archive gnu-standards autoconf-doc gettext-doc autopoint
#   libasprintf-dev libgettextpo-dev libdigest-hmac-perl libgssapi-perl
#   libcrypt-ssleay-perl libtool-doc gcj-jdk libauthen-ntlm-perl m4-doc
# The following NEW packages will be installed:
#   autoconf automake autotools-dev file gettext gettext-base intltool
#   libauthen-sasl-perl libdata-dump-perl libencode-locale-perl
#   libfile-listing-perl libfont-afm-perl libhtml-form-perl libhtml-format-perl
#   libhtml-parser-perl libhtml-tagset-perl libhtml-tree-perl
#   libhttp-cookies-perl libhttp-daemon-perl libhttp-date-perl
#   libhttp-message-perl libhttp-negotiate-perl libio-html-perl
#   libio-socket-ssl-perl liblwp-mediatypes-perl liblwp-protocol-https-perl
#   libmagic-mgc libmagic1 libmailtools-perl libnet-http-perl
#   libnet-smtp-ssl-perl libnet-ssleay-perl libsigsegv2 libtimedate-perl libtool
#   libtry-tiny-perl liburi-perl libwww-perl libwww-robotrules-perl
#   libxml-parser-perl m4 netbase perl-openssl-defaults
# 0 upgraded, 43 newly installed, 0 to remove and 41 not upgraded.
# Need to get 4,714 kB of archives.
# After this operation, 23.7 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic-mgc amd64 1:5.32-2ubuntu0.3 [184 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic1 amd64 1:5.32-2ubuntu0.3 [68.7 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 file amd64 1:5.32-2ubuntu0.3 [22.1 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/main amd64 netbase all 5.4 [12.7 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gettext-base amd64 0.19.8.1-6ubuntu0.3 [113 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsigsegv2 amd64 2.12-1 [14.7 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/main amd64 m4 amd64 1.4.18-1 [197 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/main amd64 autoconf all 2.69-11 [322 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/main amd64 autotools-dev all 20180224.1 [39.6 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic/main amd64 automake all 1:1.15.1-3ubuntu2 [509 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gettext amd64 0.19.8.1-6ubuntu0.3 [1,293 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic/main amd64 liburi-perl all 1.73-1 [77.2 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic/main amd64 libencode-locale-perl all 1.05-1 [12.3 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic/main amd64 libtimedate-perl all 2.3000-2 [37.5 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic/main amd64 libhttp-date-perl all 6.02-1 [10.4 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfile-listing-perl all 6.04-1 [9,774 B]
# Get:17 http://archive.ubuntu.com/ubuntu bionic/main amd64 libhtml-tagset-perl all 3.20-3 [12.1 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic/main amd64 libhtml-parser-perl amd64 3.72-3build1 [85.9 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic/main amd64 libhtml-tree-perl all 5.07-1 [200 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic/main amd64 libio-html-perl all 1.001-1 [14.9 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic/main amd64 liblwp-mediatypes-perl all 6.02-1 [21.7 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic/main amd64 libhttp-message-perl all 6.14-1 [72.1 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic/main amd64 libhttp-cookies-perl all 6.04-1 [17.2 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic/main amd64 libhttp-negotiate-perl all 6.00-2 [13.4 kB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic/main amd64 perl-openssl-defaults amd64 3build1 [7,012 B]
# Get:26 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libnet-ssleay-perl amd64 1.84-1ubuntu0.2 [283 kB]
# Get:27 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libio-socket-ssl-perl all 2.060-3~ubuntu18.04.1 [173 kB]
# Get:28 http://archive.ubuntu.com/ubuntu bionic/main amd64 libnet-http-perl all 6.17-1 [22.7 kB]
# Get:29 http://archive.ubuntu.com/ubuntu bionic/main amd64 liblwp-protocol-https-perl all 6.07-2 [8,284 B]
# Get:30 http://archive.ubuntu.com/ubuntu bionic/main amd64 libtry-tiny-perl all 0.30-1 [20.5 kB]
# Get:31 http://archive.ubuntu.com/ubuntu bionic/main amd64 libwww-robotrules-perl all 6.01-1 [14.1 kB]
# Get:32 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libwww-perl all 6.31-1ubuntu0.1 [137 kB]
# Get:33 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxml-parser-perl amd64 2.44-2build3 [199 kB]
# Get:34 http://archive.ubuntu.com/ubuntu bionic/universe amd64 intltool all 0.51.0-5ubuntu1 [44.6 kB]
# Get:35 http://archive.ubuntu.com/ubuntu bionic/main amd64 libdata-dump-perl all 1.23-1 [27.0 kB]
# Get:36 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfont-afm-perl all 1.20-2 [13.2 kB]
# Get:37 http://archive.ubuntu.com/ubuntu bionic/main amd64 libhtml-form-perl all 6.03-1 [23.5 kB]
# Get:38 http://archive.ubuntu.com/ubuntu bionic/main amd64 libhtml-format-perl all 2.12-1 [41.3 kB]
# Get:39 http://archive.ubuntu.com/ubuntu bionic/main amd64 libhttp-daemon-perl all 6.01-1 [17.0 kB]
# Get:40 http://archive.ubuntu.com/ubuntu bionic/main amd64 libnet-smtp-ssl-perl all 1.04-1 [5,948 B]
# Get:41 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmailtools-perl all 2.18-1 [74.0 kB]
# Get:42 http://archive.ubuntu.com/ubuntu bionic/main amd64 libtool all 2.4.6-2 [194 kB]
# Get:43 http://archive.ubuntu.com/ubuntu bionic/main amd64 libauthen-sasl-perl all 2.1600-1 [48.7 kB]
# Fetched 4,714 kB in 4s (1,236 kB/s)
# Extracting templates from packages: 100%
# Selecting previously unselected package libmagic-mgc.
# (Reading database ... 136013 files and directories currently installed.)
# Preparing to unpack .../00-libmagic-mgc_1%3a5.32-2ubuntu0.3_amd64.deb ...
# Unpacking libmagic-mgc (1:5.32-2ubuntu0.3) ...
# Selecting previously unselected package libmagic1:amd64.
# Preparing to unpack .../01-libmagic1_1%3a5.32-2ubuntu0.3_amd64.deb ...
# Unpacking libmagic1:amd64 (1:5.32-2ubuntu0.3) ...
# Selecting previously unselected package file.
# Preparing to unpack .../02-file_1%3a5.32-2ubuntu0.3_amd64.deb ...
# Unpacking file (1:5.32-2ubuntu0.3) ...
# Selecting previously unselected package netbase.
# Preparing to unpack .../03-netbase_5.4_all.deb ...
# Unpacking netbase (5.4) ...
# Selecting previously unselected package gettext-base.
# Preparing to unpack .../04-gettext-base_0.19.8.1-6ubuntu0.3_amd64.deb ...
# Unpacking gettext-base (0.19.8.1-6ubuntu0.3) ...
# Selecting previously unselected package libsigsegv2:amd64.
# Preparing to unpack .../05-libsigsegv2_2.12-1_amd64.deb ...
# Unpacking libsigsegv2:amd64 (2.12-1) ...
# Selecting previously unselected package m4.
# Preparing to unpack .../06-m4_1.4.18-1_amd64.deb ...
# Unpacking m4 (1.4.18-1) ...
# Selecting previously unselected package autoconf.
# Preparing to unpack .../07-autoconf_2.69-11_all.deb ...
# Unpacking autoconf (2.69-11) ...
# Selecting previously unselected package autotools-dev.
# Preparing to unpack .../08-autotools-dev_20180224.1_all.deb ...
# Unpacking autotools-dev (20180224.1) ...
# Selecting previously unselected package automake.
# Preparing to unpack .../09-automake_1%3a1.15.1-3ubuntu2_all.deb ...
# Unpacking automake (1:1.15.1-3ubuntu2) ...
# Selecting previously unselected package gettext.
# Preparing to unpack .../10-gettext_0.19.8.1-6ubuntu0.3_amd64.deb ...
# Unpacking gettext (0.19.8.1-6ubuntu0.3) ...
# Selecting previously unselected package liburi-perl.
# Preparing to unpack .../11-liburi-perl_1.73-1_all.deb ...
# Unpacking liburi-perl (1.73-1) ...
# Selecting previously unselected package libencode-locale-perl.
# Preparing to unpack .../12-libencode-locale-perl_1.05-1_all.deb ...
# Unpacking libencode-locale-perl (1.05-1) ...
# Selecting previously unselected package libtimedate-perl.
# Preparing to unpack .../13-libtimedate-perl_2.3000-2_all.deb ...
# Unpacking libtimedate-perl (2.3000-2) ...
# Selecting previously unselected package libhttp-date-perl.
# Preparing to unpack .../14-libhttp-date-perl_6.02-1_all.deb ...
# Unpacking libhttp-date-perl (6.02-1) ...
# Selecting previously unselected package libfile-listing-perl.
# Preparing to unpack .../15-libfile-listing-perl_6.04-1_all.deb ...
# Unpacking libfile-listing-perl (6.04-1) ...
# Selecting previously unselected package libhtml-tagset-perl.
# Preparing to unpack .../16-libhtml-tagset-perl_3.20-3_all.deb ...
# Unpacking libhtml-tagset-perl (3.20-3) ...
# Selecting previously unselected package libhtml-parser-perl.
# Preparing to unpack .../17-libhtml-parser-perl_3.72-3build1_amd64.deb ...
# Unpacking libhtml-parser-perl (3.72-3build1) ...
# Selecting previously unselected package libhtml-tree-perl.
# Preparing to unpack .../18-libhtml-tree-perl_5.07-1_all.deb ...
# Unpacking libhtml-tree-perl (5.07-1) ...
# Selecting previously unselected package libio-html-perl.
# Preparing to unpack .../19-libio-html-perl_1.001-1_all.deb ...
# Unpacking libio-html-perl (1.001-1) ...
# Selecting previously unselected package liblwp-mediatypes-perl.
# Preparing to unpack .../20-liblwp-mediatypes-perl_6.02-1_all.deb ...
# Unpacking liblwp-mediatypes-perl (6.02-1) ...
# Selecting previously unselected package libhttp-message-perl.
# Preparing to unpack .../21-libhttp-message-perl_6.14-1_all.deb ...
# Unpacking libhttp-message-perl (6.14-1) ...
# Selecting previously unselected package libhttp-cookies-perl.
# Preparing to unpack .../22-libhttp-cookies-perl_6.04-1_all.deb ...
# Unpacking libhttp-cookies-perl (6.04-1) ...
# Selecting previously unselected package libhttp-negotiate-perl.
# Preparing to unpack .../23-libhttp-negotiate-perl_6.00-2_all.deb ...
# Unpacking libhttp-negotiate-perl (6.00-2) ...
# Selecting previously unselected package perl-openssl-defaults:amd64.
# Preparing to unpack .../24-perl-openssl-defaults_3build1_amd64.deb ...
# Unpacking perl-openssl-defaults:amd64 (3build1) ...
# Selecting previously unselected package libnet-ssleay-perl.
# Preparing to unpack .../25-libnet-ssleay-perl_1.84-1ubuntu0.2_amd64.deb ...
# Unpacking libnet-ssleay-perl (1.84-1ubuntu0.2) ...
# Selecting previously unselected package libio-socket-ssl-perl.
# Preparing to unpack .../26-libio-socket-ssl-perl_2.060-3~ubuntu18.04.1_all.deb ...
# Unpacking libio-socket-ssl-perl (2.060-3~ubuntu18.04.1) ...
# Selecting previously unselected package libnet-http-perl.
# Preparing to unpack .../27-libnet-http-perl_6.17-1_all.deb ...
# Unpacking libnet-http-perl (6.17-1) ...
# Selecting previously unselected package liblwp-protocol-https-perl.
# Preparing to unpack .../28-liblwp-protocol-https-perl_6.07-2_all.deb ...
# Unpacking liblwp-protocol-https-perl (6.07-2) ...
# Selecting previously unselected package libtry-tiny-perl.
# Preparing to unpack .../29-libtry-tiny-perl_0.30-1_all.deb ...
# Unpacking libtry-tiny-perl (0.30-1) ...
# Selecting previously unselected package libwww-robotrules-perl.
# Preparing to unpack .../30-libwww-robotrules-perl_6.01-1_all.deb ...
# Unpacking libwww-robotrules-perl (6.01-1) ...
# Selecting previously unselected package libwww-perl.
# Preparing to unpack .../31-libwww-perl_6.31-1ubuntu0.1_all.deb ...
# Unpacking libwww-perl (6.31-1ubuntu0.1) ...
# Selecting previously unselected package libxml-parser-perl.
# Preparing to unpack .../32-libxml-parser-perl_2.44-2build3_amd64.deb ...
# Unpacking libxml-parser-perl (2.44-2build3) ...
# Selecting previously unselected package intltool.
# Preparing to unpack .../33-intltool_0.51.0-5ubuntu1_all.deb ...
# Unpacking intltool (0.51.0-5ubuntu1) ...
# Selecting previously unselected package libdata-dump-perl.
# Preparing to unpack .../34-libdata-dump-perl_1.23-1_all.deb ...
# Unpacking libdata-dump-perl (1.23-1) ...
# Selecting previously unselected package libfont-afm-perl.
# Preparing to unpack .../35-libfont-afm-perl_1.20-2_all.deb ...
# Unpacking libfont-afm-perl (1.20-2) ...
# Selecting previously unselected package libhtml-form-perl.
# Preparing to unpack .../36-libhtml-form-perl_6.03-1_all.deb ...
# Unpacking libhtml-form-perl (6.03-1) ...
# Selecting previously unselected package libhtml-format-perl.
# Preparing to unpack .../37-libhtml-format-perl_2.12-1_all.deb ...
# Unpacking libhtml-format-perl (2.12-1) ...
# Selecting previously unselected package libhttp-daemon-perl.
# Preparing to unpack .../38-libhttp-daemon-perl_6.01-1_all.deb ...
# Unpacking libhttp-daemon-perl (6.01-1) ...
# Selecting previously unselected package libnet-smtp-ssl-perl.
# Preparing to unpack .../39-libnet-smtp-ssl-perl_1.04-1_all.deb ...
# Unpacking libnet-smtp-ssl-perl (1.04-1) ...
# Selecting previously unselected package libmailtools-perl.
# Preparing to unpack .../40-libmailtools-perl_2.18-1_all.deb ...
# Unpacking libmailtools-perl (2.18-1) ...
# Selecting previously unselected package libtool.
# Preparing to unpack .../41-libtool_2.4.6-2_all.deb ...
# Unpacking libtool (2.4.6-2) ...
# Selecting previously unselected package libauthen-sasl-perl.
# Preparing to unpack .../42-libauthen-sasl-perl_2.1600-1_all.deb ...
# Unpacking libauthen-sasl-perl (2.1600-1) ...
# Setting up libhtml-tagset-perl (3.20-3) ...
# Setting up libtry-tiny-perl (0.30-1) ...
# Setting up libfont-afm-perl (1.20-2) ...
# Setting up libencode-locale-perl (1.05-1) ...
# Setting up libtimedate-perl (2.3000-2) ...
# Setting up libsigsegv2:amd64 (2.12-1) ...
# Setting up perl-openssl-defaults:amd64 (3build1) ...
# Setting up libio-html-perl (1.001-1) ...
# Setting up gettext-base (0.19.8.1-6ubuntu0.3) ...
# Setting up m4 (1.4.18-1) ...
# Setting up libmagic-mgc (1:5.32-2ubuntu0.3) ...
# Setting up libmagic1:amd64 (1:5.32-2ubuntu0.3) ...
# Setting up liblwp-mediatypes-perl (6.02-1) ...
# Setting up autotools-dev (20180224.1) ...
# Setting up liburi-perl (1.73-1) ...
# Setting up libdata-dump-perl (1.23-1) ...
# Setting up libhtml-parser-perl (3.72-3build1) ...
# Setting up libnet-http-perl (6.17-1) ...
# Setting up libwww-robotrules-perl (6.01-1) ...
# Setting up libauthen-sasl-perl (2.1600-1) ...
# Setting up netbase (5.4) ...
# Setting up libhttp-date-perl (6.02-1) ...
# Setting up gettext (0.19.8.1-6ubuntu0.3) ...
# Setting up libnet-ssleay-perl (1.84-1ubuntu0.2) ...
# Setting up autoconf (2.69-11) ...
# Setting up file (1:5.32-2ubuntu0.3) ...
# Setting up libio-socket-ssl-perl (2.060-3~ubuntu18.04.1) ...
# Setting up libhtml-tree-perl (5.07-1) ...
# Setting up automake (1:1.15.1-3ubuntu2) ...
# update-alternatives: using /usr/bin/automake-1.15 to provide /usr/bin/automake (automake) in auto mode
# Setting up libfile-listing-perl (6.04-1) ...
# Setting up libhttp-message-perl (6.14-1) ...
# Setting up libhttp-negotiate-perl (6.00-2) ...
# Setting up libtool (2.4.6-2) ...
# Setting up libnet-smtp-ssl-perl (1.04-1) ...
# Setting up libhtml-format-perl (2.12-1) ...
# Setting up libhttp-cookies-perl (6.04-1) ...
# Setting up libhttp-daemon-perl (6.01-1) ...
# Setting up libhtml-form-perl (6.03-1) ...
# Setting up libmailtools-perl (2.18-1) ...
# Setting up libwww-perl (6.31-1ubuntu0.1) ...
# Setting up liblwp-protocol-https-perl (6.07-2) ...
# Setting up libxml-parser-perl (2.44-2build3) ...
# Setting up intltool (0.51.0-5ubuntu1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# --2019-12-06 14:32:12--  https://github.com/mypaint/libmypaint/archive/v2.0.0-alpha.1.tar.gz
# Resolving github.com (github.com)... 192.30.255.113
# Connecting to github.com (github.com)|192.30.255.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/mypaint/libmypaint/tar.gz/v2.0.0-alpha.1 [following]
# --2019-12-06 14:32:12--  https://codeload.github.com/mypaint/libmypaint/tar.gz/v2.0.0-alpha.1
# Resolving codeload.github.com (codeload.github.com)... 192.30.255.120
# Connecting to codeload.github.com (codeload.github.com)|192.30.255.120|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/x-gzip]
# Saving to: ‘v2.0.0-alpha.1.tar.gz’
#
# v2.0.0-alpha.1.tar.     [ <=>                ] 879.09K  --.-KB/s    in 0.1s
#
# 2019-12-06 14:32:12 (6.48 MB/s) - ‘v2.0.0-alpha.1.tar.gz’ saved [900189]
#
# libmypaint-2.0.0-alpha.1/
# libmypaint-2.0.0-alpha.1/.gitignore
# libmypaint-2.0.0-alpha.1/.travis.yml
# libmypaint-2.0.0-alpha.1/CODE_OF_CONDUCT.md
# libmypaint-2.0.0-alpha.1/CONTRIBUTING.md
# libmypaint-2.0.0-alpha.1/COPYING
# libmypaint-2.0.0-alpha.1/Makefile.am
# libmypaint-2.0.0-alpha.1/PERFORMANCE
# libmypaint-2.0.0-alpha.1/README.md
# libmypaint-2.0.0-alpha.1/TODO
# libmypaint-2.0.0-alpha.1/VERSIONING.md
# libmypaint-2.0.0-alpha.1/appveyor.bat
# libmypaint-2.0.0-alpha.1/appveyor.yml
# libmypaint-2.0.0-alpha.1/autogen.sh
# libmypaint-2.0.0-alpha.1/brushmodes.c
# libmypaint-2.0.0-alpha.1/brushmodes.h
# libmypaint-2.0.0-alpha.1/brushsettings.json
# libmypaint-2.0.0-alpha.1/configure.ac
# libmypaint-2.0.0-alpha.1/doc/
# libmypaint-2.0.0-alpha.1/doc/.gitignore
# libmypaint-2.0.0-alpha.1/doc/Doxyfile
# libmypaint-2.0.0-alpha.1/doc/Makefile.am
# libmypaint-2.0.0-alpha.1/doc/images/
# libmypaint-2.0.0-alpha.1/doc/images/brushdab_geometry.odg
# libmypaint-2.0.0-alpha.1/doc/images/brushdab_saturation.png
# libmypaint-2.0.0-alpha.1/doc/images/brushlib_concept.odg
# libmypaint-2.0.0-alpha.1/doc/images/rendered_dab_whitbg.png
# libmypaint-2.0.0-alpha.1/doc/images/smudge_math.png
# libmypaint-2.0.0-alpha.1/doc/images/stroke2dabs.png
# libmypaint-2.0.0-alpha.1/doc/images/stroke2dabs.svg
# libmypaint-2.0.0-alpha.1/doc/scripts/
# libmypaint-2.0.0-alpha.1/doc/scripts/dab_hardness_plot.py
# libmypaint-2.0.0-alpha.1/doc/source/
# libmypaint-2.0.0-alpha.1/doc/source/conf.py
# libmypaint-2.0.0-alpha.1/doc/source/index.rst
# libmypaint-2.0.0-alpha.1/examples/
# libmypaint-2.0.0-alpha.1/examples/gegl.py
# libmypaint-2.0.0-alpha.1/examples/minimal.c
# libmypaint-2.0.0-alpha.1/fastapprox/
# libmypaint-2.0.0-alpha.1/fastapprox/Makefile.am.local
# libmypaint-2.0.0-alpha.1/fastapprox/cast.h
# libmypaint-2.0.0-alpha.1/fastapprox/fasterf.h
# libmypaint-2.0.0-alpha.1/fastapprox/fastexp.h
# libmypaint-2.0.0-alpha.1/fastapprox/fastgamma.h
# libmypaint-2.0.0-alpha.1/fastapprox/fasthyperbolic.h
# libmypaint-2.0.0-alpha.1/fastapprox/fastlambertw.h
# libmypaint-2.0.0-alpha.1/fastapprox/fastlog.h
# libmypaint-2.0.0-alpha.1/fastapprox/fastonebigheader.h
# libmypaint-2.0.0-alpha.1/fastapprox/fastpow.h
# libmypaint-2.0.0-alpha.1/fastapprox/fastsigmoid.h
# libmypaint-2.0.0-alpha.1/fastapprox/fasttrig.h
# libmypaint-2.0.0-alpha.1/fastapprox/sse.h
# libmypaint-2.0.0-alpha.1/fifo.c
# libmypaint-2.0.0-alpha.1/fifo.h
# libmypaint-2.0.0-alpha.1/gegl/
# libmypaint-2.0.0-alpha.1/gegl/Makefile.am
# libmypaint-2.0.0-alpha.1/gegl/libmypaint-gegl.pc.in
# libmypaint-2.0.0-alpha.1/gegl/mypaint-gegl-surface.c
# libmypaint-2.0.0-alpha.1/gegl/mypaint-gegl-surface.h
# libmypaint-2.0.0-alpha.1/generate.py
# libmypaint-2.0.0-alpha.1/glib/
# libmypaint-2.0.0-alpha.1/glib/mypaint-brush.c
# libmypaint-2.0.0-alpha.1/glib/mypaint-brush.h
# libmypaint-2.0.0-alpha.1/glib/mypaint-gegl-glib.c
# libmypaint-2.0.0-alpha.1/glib/mypaint-gegl-glib.h
# libmypaint-2.0.0-alpha.1/helpers.c
# libmypaint-2.0.0-alpha.1/helpers.h
# libmypaint-2.0.0-alpha.1/libmypaint.c
# libmypaint-2.0.0-alpha.1/libmypaint.pc.in
# libmypaint-2.0.0-alpha.1/m4macros/
# libmypaint-2.0.0-alpha.1/m4macros/ax_check_compile_flag.m4
# libmypaint-2.0.0-alpha.1/m4macros/ax_check_link_flag.m4
# libmypaint-2.0.0-alpha.1/m4macros/introspection.m4
# libmypaint-2.0.0-alpha.1/m4macros/pythondev.m4
# libmypaint-2.0.0-alpha.1/mypaint-brush-settings.c
# libmypaint-2.0.0-alpha.1/mypaint-brush-settings.h
# libmypaint-2.0.0-alpha.1/mypaint-brush.c
# libmypaint-2.0.0-alpha.1/mypaint-brush.h
# libmypaint-2.0.0-alpha.1/mypaint-config.h
# libmypaint-2.0.0-alpha.1/mypaint-fixed-tiled-surface.c
# libmypaint-2.0.0-alpha.1/mypaint-fixed-tiled-surface.h
# libmypaint-2.0.0-alpha.1/mypaint-glib-compat.h
# libmypaint-2.0.0-alpha.1/mypaint-mapping.c
# libmypaint-2.0.0-alpha.1/mypaint-mapping.h
# libmypaint-2.0.0-alpha.1/mypaint-rectangle.c
# libmypaint-2.0.0-alpha.1/mypaint-rectangle.h
# libmypaint-2.0.0-alpha.1/mypaint-surface.c
# libmypaint-2.0.0-alpha.1/mypaint-surface.h
# libmypaint-2.0.0-alpha.1/mypaint-tiled-surface.c
# libmypaint-2.0.0-alpha.1/mypaint-tiled-surface.h
# libmypaint-2.0.0-alpha.1/mypaint.c
# libmypaint-2.0.0-alpha.1/mypaint.h
# libmypaint-2.0.0-alpha.1/operationqueue.c
# libmypaint-2.0.0-alpha.1/operationqueue.h
# libmypaint-2.0.0-alpha.1/po/
# libmypaint-2.0.0-alpha.1/po/LINGUAS
# libmypaint-2.0.0-alpha.1/po/POTFILES.in
# libmypaint-2.0.0-alpha.1/po/README.md
# libmypaint-2.0.0-alpha.1/po/ar.po
# libmypaint-2.0.0-alpha.1/po/ca.po
# libmypaint-2.0.0-alpha.1/po/cs.po
# libmypaint-2.0.0-alpha.1/po/da.po
# libmypaint-2.0.0-alpha.1/po/de.po
# libmypaint-2.0.0-alpha.1/po/en_CA.po
# libmypaint-2.0.0-alpha.1/po/en_GB.po
# libmypaint-2.0.0-alpha.1/po/es.po
# libmypaint-2.0.0-alpha.1/po/es_ES.po
# libmypaint-2.0.0-alpha.1/po/fa.po
# libmypaint-2.0.0-alpha.1/po/fi.po
# libmypaint-2.0.0-alpha.1/po/fr.po
# libmypaint-2.0.0-alpha.1/po/he.po
# libmypaint-2.0.0-alpha.1/po/hu.po
# libmypaint-2.0.0-alpha.1/po/id.po
# libmypaint-2.0.0-alpha.1/po/it.po
# libmypaint-2.0.0-alpha.1/po/ja.po
# libmypaint-2.0.0-alpha.1/po/kab.po
# libmypaint-2.0.0-alpha.1/po/ko.po
# libmypaint-2.0.0-alpha.1/po/libmypaint.pot
# libmypaint-2.0.0-alpha.1/po/nb.po
# libmypaint-2.0.0-alpha.1/po/nn_NO.po
# libmypaint-2.0.0-alpha.1/po/pl.po
# libmypaint-2.0.0-alpha.1/po/pt_BR.po
# libmypaint-2.0.0-alpha.1/po/ro.po
# libmypaint-2.0.0-alpha.1/po/ru.po
# libmypaint-2.0.0-alpha.1/po/sc.po
# libmypaint-2.0.0-alpha.1/po/sk.po
# libmypaint-2.0.0-alpha.1/po/sl.po
# libmypaint-2.0.0-alpha.1/po/sv.po
# libmypaint-2.0.0-alpha.1/po/tr.po
# libmypaint-2.0.0-alpha.1/po/uk.po
# libmypaint-2.0.0-alpha.1/po/zh_CN.po
# libmypaint-2.0.0-alpha.1/po/zh_TW.po
# libmypaint-2.0.0-alpha.1/rng-double.c
# libmypaint-2.0.0-alpha.1/rng-double.h
# libmypaint-2.0.0-alpha.1/tests/
# libmypaint-2.0.0-alpha.1/tests/.gitignore
# libmypaint-2.0.0-alpha.1/tests/Makefile.am
# libmypaint-2.0.0-alpha.1/tests/brushes/
# libmypaint-2.0.0-alpha.1/tests/brushes/bad/
# libmypaint-2.0.0-alpha.1/tests/brushes/bad/bad_setting_types_1.myb
# libmypaint-2.0.0-alpha.1/tests/brushes/bad/bad_setting_types_2.myb
# libmypaint-2.0.0-alpha.1/tests/brushes/bad/bad_setting_types_3.myb
# libmypaint-2.0.0-alpha.1/tests/brushes/bad/bad_setting_types_4.myb
# libmypaint-2.0.0-alpha.1/tests/brushes/bad/empty.bad-myb
# libmypaint-2.0.0-alpha.1/tests/brushes/bad/entirely_unknown_settings.bad-myb
# libmypaint-2.0.0-alpha.1/tests/brushes/bad/missing_settings.bad-myb
# libmypaint-2.0.0-alpha.1/tests/brushes/bad/missing_version.bad-myb
# libmypaint-2.0.0-alpha.1/tests/brushes/bad/some_unknown_settings.myb
# libmypaint-2.0.0-alpha.1/tests/brushes/bad/truncated.bad-myb
# libmypaint-2.0.0-alpha.1/tests/brushes/bulk.myb
# libmypaint-2.0.0-alpha.1/tests/brushes/charcoal.myb
# libmypaint-2.0.0-alpha.1/tests/brushes/coarse_bulk_2.myb
# libmypaint-2.0.0-alpha.1/tests/brushes/impressionism.myb
# libmypaint-2.0.0-alpha.1/tests/brushes/modelling.myb
# libmypaint-2.0.0-alpha.1/tests/ctests.py
# libmypaint-2.0.0-alpha.1/tests/events/
# libmypaint-2.0.0-alpha.1/tests/events/painting30sec.dat
# libmypaint-2.0.0-alpha.1/tests/gegl/
# libmypaint-2.0.0-alpha.1/tests/gegl/Makefile.am
# libmypaint-2.0.0-alpha.1/tests/gegl/test-gegl-surface.c
# libmypaint-2.0.0-alpha.1/tests/mypaint-benchmark.c
# libmypaint-2.0.0-alpha.1/tests/mypaint-benchmark.h
# libmypaint-2.0.0-alpha.1/tests/mypaint-test-surface.c
# libmypaint-2.0.0-alpha.1/tests/mypaint-test-surface.h
# libmypaint-2.0.0-alpha.1/tests/mypaint-utils-stroke-player.c
# libmypaint-2.0.0-alpha.1/tests/mypaint-utils-stroke-player.h
# libmypaint-2.0.0-alpha.1/tests/test-brush-load.c
# libmypaint-2.0.0-alpha.1/tests/test-brush-persistence.c
# libmypaint-2.0.0-alpha.1/tests/test-details.c
# libmypaint-2.0.0-alpha.1/tests/test-fixed-tiled-surface.c
# libmypaint-2.0.0-alpha.1/tests/test-rng.c
# libmypaint-2.0.0-alpha.1/tests/test_ctests.py
# libmypaint-2.0.0-alpha.1/tests/testutils.c
# libmypaint-2.0.0-alpha.1/tests/testutils.h
# libmypaint-2.0.0-alpha.1/tiled-surface-private.h
# libmypaint-2.0.0-alpha.1/tilemap.c
# libmypaint-2.0.0-alpha.1/tilemap.h
# libmypaint-2.0.0-alpha.1/utils.c
# libmypaint-2.0.0-alpha.1/utils.h
#
# I am testing that you have the tools required to build
# libmypaint from git. This test is not foolproof.
#
# checking for libtool >= 1.5 ... Major version might be too new (2.4.6)
# checking for autoconf >= 2.62 ... yes (version 2.69)
# checking for automake >= 1.13 ... yes (version 1.15.1)
# checking for intltool >= 0.40.1 ... yes (version 0.51.0)
# libtoolize: putting auxiliary files in '.'.
# libtoolize: linking file './ltmain.sh'
# libtoolize: putting macros in AC_CONFIG_MACRO_DIRS, 'm4macros'.
# libtoolize: linking file 'm4macros/libtool.m4'
# libtoolize: linking file 'm4macros/ltoptions.m4'
# libtoolize: linking file 'm4macros/ltsugar.m4'
# libtoolize: linking file 'm4macros/ltversion.m4'
# libtoolize: linking file 'm4macros/lt~obsolete.m4'
# Writing mypaint-brush-settings-gen.h
# Writing brushsettings-gen.h
# configure.ac:86: installing './ar-lib'
# configure.ac:84: installing './compile'
# configure.ac:92: installing './config.guess'
# configure.ac:92: installing './config.sub'
# configure.ac:60: installing './install-sh'
# configure.ac:60: installing './missing'
# Makefile.am: installing './depcomp'
# parallel-tests: installing './test-driver'
# checking for a BSD-compatible install... /usr/bin/install -c
# checking whether build environment is sane... yes
# checking for a thread-safe mkdir -p... /bin/mkdir -p
# checking for gawk... no
# checking for mawk... mawk
# checking whether make sets $(MAKE)... yes
# checking whether make supports nested variables... yes
# checking for gcc... gcc
# checking whether the C compiler works... yes
# checking for C compiler default output file name... a.out
# checking for suffix of executables...
# checking whether we are cross compiling... no
# checking for suffix of object files... o
# checking whether we are using the GNU C compiler... yes
# checking whether gcc accepts -g... yes
# checking for gcc option to accept ISO C89... none needed
# checking whether gcc understands -c and -o together... yes
# checking for style of include used by make... GNU
# checking dependency style of gcc... gcc3
# checking for gcc option to accept ISO C99... none needed
# checking for ar... ar
# checking the archiver (ar) interface... ar
# checking build system type... x86_64-pc-linux-gnu
# checking host system type... x86_64-pc-linux-gnu
# checking how to print strings... printf
# checking for a sed that does not truncate output... /bin/sed
# checking for grep that handles long lines and -e... /bin/grep
# checking for egrep... /bin/grep -E
# checking for fgrep... /bin/grep -F
# checking for ld used by gcc... /usr/bin/ld
# checking if the linker (/usr/bin/ld) is GNU ld... yes
# checking for BSD- or MS-compatible name lister (nm)... /usr/bin/nm -B
# checking the name lister (/usr/bin/nm -B) interface... BSD nm
# checking whether ln -s works... yes
# checking the maximum length of command line arguments... 1572864
# checking how to convert x86_64-pc-linux-gnu file names to x86_64-pc-linux-gnu format... func_convert_file_noop
# checking how to convert x86_64-pc-linux-gnu file names to toolchain format... func_convert_file_noop
# checking for /usr/bin/ld option to reload object files... -r
# checking for objdump... objdump
# checking how to recognize dependent libraries... pass_all
# checking for dlltool... no
# checking how to associate runtime and link libraries... printf %s\n
# checking for archiver @FILE support... @
# checking for strip... strip
# checking for ranlib... ranlib
# checking command to parse /usr/bin/nm -B output from gcc object... ok
# checking for sysroot... no
# checking for a working dd... /bin/dd
# checking how to truncate binary pipes... /bin/dd bs=4096 count=1
# checking for mt... no
# checking if : is a manifest tool... no
# checking how to run the C preprocessor... gcc -E
# checking for ANSI C header files... yes
# checking for sys/types.h... yes
# checking for sys/stat.h... yes
# checking for stdlib.h... yes
# checking for string.h... yes
# checking for memory.h... yes
# checking for strings.h... yes
# checking for inttypes.h... yes
# checking for stdint.h... yes
# checking for unistd.h... yes
# checking for dlfcn.h... yes
# checking for objdir... .libs
# checking if gcc supports -fno-rtti -fno-exceptions... no
# checking for gcc option to produce PIC... -fPIC -DPIC
# checking if gcc PIC flag -fPIC -DPIC works... yes
# checking if gcc static flag -static works... yes
# checking if gcc supports -c -o file.o... yes
# checking if gcc supports -c -o file.o... (cached) yes
# checking whether the gcc linker (/usr/bin/ld -m elf_x86_64) supports shared libraries... yes
# checking whether -lc should be explicitly linked in... no
# checking dynamic linker characteristics... GNU/Linux ld.so
# checking how to hardcode library paths into programs... immediate
# checking whether stripping libraries is possible... yes
# checking if libtool supports shared libraries... yes
# checking whether to build shared libraries... yes
# checking whether to build static libraries... no
# checking whether to enable maintainer-specific portions of Makefiles... yes
# checking for pkg-config... /usr/bin/pkg-config
# checking pkg-config is at least version 0.16... yes
# checking for platform... unix
# checking whether to turn on debugging... no
# checking whether to turn on profiling... no
# checking for JSON... yes
# checking for library containing floorf... -lm
# checking for library containing powf... none required
# checking for library containing expf... none required
# checking for library containing fabsf... none required
# checking whether C compiler accepts -fsanitize=undefined... yes
# checking whether the linker accepts -fsanitize=undefined... yes
# checking whether NLS is requested... yes
# checking for intltool-update... /usr/bin/intltool-update
# checking for intltool-merge... /usr/bin/intltool-merge
# checking for intltool-extract... /usr/bin/intltool-extract
# checking for xgettext... /usr/bin/xgettext
# checking for msgmerge... /usr/bin/msgmerge
# checking for msgfmt... /usr/bin/msgfmt
# checking for gmsgfmt... /usr/bin/msgfmt
# checking for perl... /usr/bin/perl
# checking for perl >= 5.8.1... 5.26.1
# checking for XML::Parser... ok
# checking locale.h usability... yes
# checking locale.h presence... yes
# checking for locale.h... yes
# checking for LC_MESSAGES... yes
# checking for CFPreferencesCopyAppValue... no
# checking for CFLocaleCopyCurrent... no
# checking libintl.h usability... yes
# checking libintl.h presence... yes
# checking for libintl.h... yes
# checking for ngettext in libc... yes
# checking for dgettext in libc... yes
# checking for bind_textdomain_codeset... yes
# checking for msgfmt... (cached) /usr/bin/msgfmt
# checking for dcgettext... yes
# checking if msgfmt accepts -c... yes
# checking for gmsgfmt... (cached) /usr/bin/msgfmt
# checking for xgettext... (cached) /usr/bin/xgettext
# checking for library containing dgettext... none required
# checking for gobject-introspection... yes
# checking for GLIB... yes
# checking that generated files are newer than configure... done
# configure: creating ./config.status
# config.status: creating doc/Makefile
# config.status: creating gegl/libmypaint-gegl-2.0.pc
# config.status: creating gegl/Makefile
# config.status: creating libmypaint-2.0.pc
# config.status: creating Makefile
# config.status: creating po/Makefile.in
# config.status: creating tests/Makefile
# config.status: creating tests/gegl/Makefile
# config.status: creating config.h
# config.status: executing depfiles commands
# config.status: executing libtool commands
# config.status: executing default-1 commands
# config.status: executing po/stamp-it commands
#
#   Configured libmypaint 2.0.0-alpha
#
# Making install in .
# make[1]: Entering directory '/content/libmypaint'
# depbase=`echo brushmodes.lo | sed 's|[^/]*$|.deps/&|;s|\.lo$||'`;\
# /bin/bash ./libtool  --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I.    -I/usr/include/json-c -I/usr/include/glib-2.0 -I/usr/lib/x86_64-linux-gnu/glib-2.0/include -D_POSIX_C_SOURCE=200809L -g -O2 -MT brushmodes.lo -MD -MP -MF $depbase.Tpo -c -o brushmodes.lo brushmodes.c &&\
# mv -f $depbase.Tpo $depbase.Plo
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/usr/include/json-c -I/usr/include/glib-2.0 -I/usr/lib/x86_64-linux-gnu/glib-2.0/include -D_POSIX_C_SOURCE=200809L -g -O2 -MT brushmodes.lo -MD -MP -MF .deps/brushmodes.Tpo -c brushmodes.c  -fPIC -DPIC -o .libs/brushmodes.o
# depbase=`echo fifo.lo | sed 's|[^/]*$|.deps/&|;s|\.lo$||'`;\
# /bin/bash ./libtool  --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I.    -I/usr/include/json-c -I/usr/include/glib-2.0 -I/usr/lib/x86_64-linux-gnu/glib-2.0/include -D_POSIX_C_SOURCE=200809L -g -O2 -MT fifo.lo -MD -MP -MF $depbase.Tpo -c -o fifo.lo fifo.c &&\
# mv -f $depbase.Tpo $depbase.Plo
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/usr/include/json-c -I/usr/include/glib-2.0 -I/usr/lib/x86_64-linux-gnu/glib-2.0/include -D_POSIX_C_SOURCE=200809L -g -O2 -MT fifo.lo -MD -MP -MF .deps/fifo.Tpo -c fifo.c  -fPIC -DPIC -o .libs/fifo.o
# depbase=`echo helpers.lo | sed 's|[^/]*$|.deps/&|;s|\.lo$||'`;\
# /bin/bash ./libtool  --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I.    -I/usr/include/json-c -I/usr/include/glib-2.0 -I/usr/lib/x86_64-linux-gnu/glib-2.0/include -D_POSIX_C_SOURCE=200809L -g -O2 -MT helpers.lo -MD -MP -MF $depbase.Tpo -c -o helpers.lo helpers.c &&\
# mv -f $depbase.Tpo $depbase.Plo
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/usr/include/json-c -I/usr/include/glib-2.0 -I/usr/lib/x86_64-linux-gnu/glib-2.0/include -D_POSIX_C_SOURCE=200809L -g -O2 -MT helpers.lo -MD -MP -MF .deps/helpers.Tpo -c helpers.c  -fPIC -DPIC -o .libs/helpers.o
# depbase=`echo mypaint-mapping.lo | sed 's|[^/]*$|.deps/&|;s|\.lo$||'`;\
# /bin/bash ./libtool  --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I.    -I/usr/include/json-c -I/usr/include/glib-2.0 -I/usr/lib/x86_64-linux-gnu/glib-2.0/include -D_POSIX_C_SOURCE=200809L -g -O2 -MT mypaint-mapping.lo -MD -MP -MF $depbase.Tpo -c -o mypaint-mapping.lo mypaint-mapping.c &&\
# mv -f $depbase.Tpo $depbase.Plo
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/usr/include/json-c -I/usr/include/glib-2.0 -I/usr/lib/x86_64-linux-gnu/glib-2.0/include -D_POSIX_C_SOURCE=200809L -g -O2 -MT mypaint-mapping.lo -MD -MP -MF .deps/mypaint-mapping.Tpo -c mypaint-mapping.c  -fPIC -DPIC -o .libs/mypaint-mapping.o
# depbase=`echo mypaint.lo | sed 's|[^/]*$|.deps/&|;s|\.lo$||'`;\
# /bin/bash ./libtool  --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I.    -I/usr/include/json-c -I/usr/include/glib-2.0 -I/usr/lib/x86_64-linux-gnu/glib-2.0/include -D_POSIX_C_SOURCE=200809L -g -O2 -MT mypaint.lo -MD -MP -MF $depbase.Tpo -c -o mypaint.lo mypaint.c &&\
# mv -f $depbase.Tpo $depbase.Plo
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/usr/include/json-c -I/usr/include/glib-2.0 -I/usr/lib/x86_64-linux-gnu/glib-2.0/include -D_POSIX_C_SOURCE=200809L -g -O2 -MT mypaint.lo -MD -MP -MF .deps/mypaint.Tpo -c mypaint.c  -fPIC -DPIC -o .libs/mypaint.o
# depbase=`echo mypaint-brush.lo | sed 's|[^/]*$|.deps/&|;s|\.lo$||'`;\
# /bin/bash ./libtool  --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I.    -I/usr/include/json-c -I/usr/include/glib-2.0 -I/usr/lib/x86_64-linux-gnu/glib-2.0/include -D_POSIX_C_SOURCE=200809L -g -O2 -MT mypaint-brush.lo -MD -MP -MF $depbase.Tpo -c -o mypaint-brush.lo mypaint-brush.c &&\
# mv -f $depbase.Tpo $depbase.Plo
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/usr/include/json-c -I/usr/include/glib-2.0 -I/usr/lib/x86_64-linux-gnu/glib-2.0/include -D_POSIX_C_SOURCE=200809L -g -O2 -MT mypaint-brush.lo -MD -MP -MF .deps/mypaint-brush.Tpo -c mypaint-brush.c  -fPIC -DPIC -o .libs/mypaint-brush.o
# depbase=`echo mypaint-brush-settings.lo | sed 's|[^/]*$|.deps/&|;s|\.lo$||'`;\
# /bin/bash ./libtool  --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I.    -I/usr/include/json-c -I/usr/include/glib-2.0 -I/usr/lib/x86_64-linux-gnu/glib-2.0/include -D_POSIX_C_SOURCE=200809L -g -O2 -MT mypaint-brush-settings.lo -MD -MP -MF $depbase.Tpo -c -o mypaint-brush-settings.lo mypaint-brush-settings.c &&\
# mv -f $depbase.Tpo $depbase.Plo
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/usr/include/json-c -I/usr/include/glib-2.0 -I/usr/lib/x86_64-linux-gnu/glib-2.0/include -D_POSIX_C_SOURCE=200809L -g -O2 -MT mypaint-brush-settings.lo -MD -MP -MF .deps/mypaint-brush-settings.Tpo -c mypaint-brush-settings.c  -fPIC -DPIC -o .libs/mypaint-brush-settings.o
# mypaint-brush-settings.c:24:0: warning: "GETTEXT_PACKAGE" redefined
#  #define GETTEXT_PACKAGE "libmypaint"
#
# In file included from mypaint-brush-settings.c:17:0:
# ./config.h:8:0: note: this is the location of the previous definition
#  #define GETTEXT_PACKAGE "libmypaint-2.0"
#
# depbase=`echo mypaint-fixed-tiled-surface.lo | sed 's|[^/]*$|.deps/&|;s|\.lo$||'`;\
# /bin/bash ./libtool  --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I.    -I/usr/include/json-c -I/usr/include/glib-2.0 -I/usr/lib/x86_64-linux-gnu/glib-2.0/include -D_POSIX_C_SOURCE=200809L -g -O2 -MT mypaint-fixed-tiled-surface.lo -MD -MP -MF $depbase.Tpo -c -o mypaint-fixed-tiled-surface.lo mypaint-fixed-tiled-surface.c &&\
# mv -f $depbase.Tpo $depbase.Plo
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/usr/include/json-c -I/usr/include/glib-2.0 -I/usr/lib/x86_64-linux-gnu/glib-2.0/include -D_POSIX_C_SOURCE=200809L -g -O2 -MT mypaint-fixed-tiled-surface.lo -MD -MP -MF .deps/mypaint-fixed-tiled-surface.Tpo -c mypaint-fixed-tiled-surface.c  -fPIC -DPIC -o .libs/mypaint-fixed-tiled-surface.o
# depbase=`echo mypaint-rectangle.lo | sed 's|[^/]*$|.deps/&|;s|\.lo$||'`;\
# /bin/bash ./libtool  --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I.    -I/usr/include/json-c -I/usr/include/glib-2.0 -I/usr/lib/x86_64-linux-gnu/glib-2.0/include -D_POSIX_C_SOURCE=200809L -g -O2 -MT mypaint-rectangle.lo -MD -MP -MF $depbase.Tpo -c -o mypaint-rectangle.lo mypaint-rectangle.c &&\
# mv -f $depbase.Tpo $depbase.Plo
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/usr/include/json-c -I/usr/include/glib-2.0 -I/usr/lib/x86_64-linux-gnu/glib-2.0/include -D_POSIX_C_SOURCE=200809L -g -O2 -MT mypaint-rectangle.lo -MD -MP -MF .deps/mypaint-rectangle.Tpo -c mypaint-rectangle.c  -fPIC -DPIC -o .libs/mypaint-rectangle.o
# depbase=`echo mypaint-surface.lo | sed 's|[^/]*$|.deps/&|;s|\.lo$||'`;\
# /bin/bash ./libtool  --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I.    -I/usr/include/json-c -I/usr/include/glib-2.0 -I/usr/lib/x86_64-linux-gnu/glib-2.0/include -D_POSIX_C_SOURCE=200809L -g -O2 -MT mypaint-surface.lo -MD -MP -MF $depbase.Tpo -c -o mypaint-surface.lo mypaint-surface.c &&\
# mv -f $depbase.Tpo $depbase.Plo
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/usr/include/json-c -I/usr/include/glib-2.0 -I/usr/lib/x86_64-linux-gnu/glib-2.0/include -D_POSIX_C_SOURCE=200809L -g -O2 -MT mypaint-surface.lo -MD -MP -MF .deps/mypaint-surface.Tpo -c mypaint-surface.c  -fPIC -DPIC -o .libs/mypaint-surface.o
# depbase=`echo mypaint-tiled-surface.lo | sed 's|[^/]*$|.deps/&|;s|\.lo$||'`;\
# /bin/bash ./libtool  --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I.    -I/usr/include/json-c -I/usr/include/glib-2.0 -I/usr/lib/x86_64-linux-gnu/glib-2.0/include -D_POSIX_C_SOURCE=200809L -g -O2 -MT mypaint-tiled-surface.lo -MD -MP -MF $depbase.Tpo -c -o mypaint-tiled-surface.lo mypaint-tiled-surface.c &&\
# mv -f $depbase.Tpo $depbase.Plo
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/usr/include/json-c -I/usr/include/glib-2.0 -I/usr/lib/x86_64-linux-gnu/glib-2.0/include -D_POSIX_C_SOURCE=200809L -g -O2 -MT mypaint-tiled-surface.lo -MD -MP -MF .deps/mypaint-tiled-surface.Tpo -c mypaint-tiled-surface.c  -fPIC -DPIC -o .libs/mypaint-tiled-surface.o
# depbase=`echo operationqueue.lo | sed 's|[^/]*$|.deps/&|;s|\.lo$||'`;\
# /bin/bash ./libtool  --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I.    -I/usr/include/json-c -I/usr/include/glib-2.0 -I/usr/lib/x86_64-linux-gnu/glib-2.0/include -D_POSIX_C_SOURCE=200809L -g -O2 -MT operationqueue.lo -MD -MP -MF $depbase.Tpo -c -o operationqueue.lo operationqueue.c &&\
# mv -f $depbase.Tpo $depbase.Plo
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/usr/include/json-c -I/usr/include/glib-2.0 -I/usr/lib/x86_64-linux-gnu/glib-2.0/include -D_POSIX_C_SOURCE=200809L -g -O2 -MT operationqueue.lo -MD -MP -MF .deps/operationqueue.Tpo -c operationqueue.c  -fPIC -DPIC -o .libs/operationqueue.o
# depbase=`echo rng-double.lo | sed 's|[^/]*$|.deps/&|;s|\.lo$||'`;\
# ...
# copying backgrounds/ramon/HR_Wall_Paper.png -> /content/local/./share/mypaint/backgrounds/ramon
# copying backgrounds/ramon/HR_Canvas 01.png -> /content/local/./share/mypaint/backgrounds/ramon
# copying backgrounds/ramon/readme_papers.txt -> /content/local/./share/mypaint/backgrounds/ramon
# copying backgrounds/ramon/HR_WaterColor.png -> /content/local/./share/mypaint/backgrounds/ramon
# copying backgrounds/ramon/HR_PastelPaper 02.png -> /content/local/./share/mypaint/backgrounds/ramon
# copying backgrounds/ramon/HR_SketchPaper 02.png -> /content/local/./share/mypaint/backgrounds/ramon
# copying backgrounds/ramon/HR_RoughPaper.png -> /content/local/./share/mypaint/backgrounds/ramon
# copying backgrounds/ramon/HR_PastelPaper 01.png -> /content/local/./share/mypaint/backgrounds/ramon
# copying backgrounds/ramon/HR_Canvas 02.png -> /content/local/./share/mypaint/backgrounds/ramon
# copying backgrounds/ramon/HR_SketchPaper.png -> /content/local/./share/mypaint/backgrounds/ramon
# copying backgrounds/ramon/HR_Cork.png -> /content/local/./share/mypaint/backgrounds/ramon
# creating /content/local/share/mypaint/backgrounds/mrmamurk
# copying backgrounds/mrmamurk/mamurk_e_6.png -> /content/local/./share/mypaint/backgrounds/mrmamurk
# copying backgrounds/mrmamurk/mamurk_d_4.png -> /content/local/./share/mypaint/backgrounds/mrmamurk
# copying backgrounds/mrmamurk/mamurk_b_4.png -> /content/local/./share/mypaint/backgrounds/mrmamurk
# copying backgrounds/mrmamurk/mamurk_e_2.png -> /content/local/./share/mypaint/backgrounds/mrmamurk
# copying backgrounds/mrmamurk/mamurk_b_6.png -> /content/local/./share/mypaint/backgrounds/mrmamurk
# copying backgrounds/mrmamurk/mamurk_e_5.png -> /content/local/./share/mypaint/backgrounds/mrmamurk
# copying backgrounds/mrmamurk/mamurk_b_5.png -> /content/local/./share/mypaint/backgrounds/mrmamurk
# copying backgrounds/mrmamurk/mamurk_c_3.png -> /content/local/./share/mypaint/backgrounds/mrmamurk
# copying backgrounds/mrmamurk/mamurk_a_1.png -> /content/local/./share/mypaint/backgrounds/mrmamurk
# copying backgrounds/mrmamurk/mamurk_d_1.png -> /content/local/./share/mypaint/backgrounds/mrmamurk
# copying backgrounds/mrmamurk/mamurk_e_4.png -> /content/local/./share/mypaint/backgrounds/mrmamurk
# copying backgrounds/mrmamurk/mamurk_f_3.png -> /content/local/./share/mypaint/backgrounds/mrmamurk
# copying backgrounds/mrmamurk/MrMamurk_readme.txt -> /content/local/./share/mypaint/backgrounds/mrmamurk
# copying backgrounds/mrmamurk/mamurk_e_3.png -> /content/local/./share/mypaint/backgrounds/mrmamurk
# copying backgrounds/mrmamurk/mamurk_f_2.png -> /content/local/./share/mypaint/backgrounds/mrmamurk
# copying backgrounds/mrmamurk/mamurk_d_2.png -> /content/local/./share/mypaint/backgrounds/mrmamurk
# copying backgrounds/mrmamurk/mamurk_b_1.png -> /content/local/./share/mypaint/backgrounds/mrmamurk
# copying backgrounds/mrmamurk/mamurk_c_1.png -> /content/local/./share/mypaint/backgrounds/mrmamurk
# copying backgrounds/mrmamurk/mamurk_c_2.png -> /content/local/./share/mypaint/backgrounds/mrmamurk
# copying backgrounds/mrmamurk/mamurk_d_3.png -> /content/local/./share/mypaint/backgrounds/mrmamurk
# copying backgrounds/mrmamurk/mamurk_b_2.png -> /content/local/./share/mypaint/backgrounds/mrmamurk
# copying backgrounds/mrmamurk/mamurk_a_2.png -> /content/local/./share/mypaint/backgrounds/mrmamurk
# copying backgrounds/mrmamurk/mamurk_f_1.png -> /content/local/./share/mypaint/backgrounds/mrmamurk
# copying backgrounds/mrmamurk/mamurk_c_4.png -> /content/local/./share/mypaint/backgrounds/mrmamurk
# copying backgrounds/mrmamurk/mamurk_e_1.png -> /content/local/./share/mypaint/backgrounds/mrmamurk
# copying backgrounds/mrmamurk/mamurk_b_3.png -> /content/local/./share/mypaint/backgrounds/mrmamurk
# copying backgrounds/mrmamurk/mamurk_f_4.png -> /content/local/./share/mypaint/backgrounds/mrmamurk
# creating /content/local/share/mypaint/palettes
# copying palettes/MyPaint_Default.gpl -> /content/local/./share/mypaint/palettes/
# copying palettes/Pastels.gpl -> /content/local/./share/mypaint/palettes/
# copying palettes/Muted.gpl -> /content/local/./share/mypaint/palettes/
# copying palettes/Greys16.gpl -> /content/local/./share/mypaint/palettes/
# copying palettes/Reds_And_Purples.gpl -> /content/local/./share/mypaint/palettes/
# copying palettes/Ubuntu.gpl -> /content/local/./share/mypaint/palettes/
# copying palettes/Watercolor.gpl -> /content/local/./share/mypaint/palettes/
# copying palettes/Browns_And_Yellows.gpl -> /content/local/./share/mypaint/palettes/
# copying palettes/Creative_Commons.gpl -> /content/local/./share/mypaint/palettes/
# copying palettes/Visibone.gpl -> /content/local/./share/mypaint/palettes/
# copying palettes/Tango_Palette.gpl -> /content/local/./share/mypaint/palettes/
# copying palettes/Warm_Colors.gpl -> /content/local/./share/mypaint/palettes/
# copying palettes/GIMP_Default.gpl -> /content/local/./share/mypaint/palettes/
# copying palettes/All_color_choice.gpl -> /content/local/./share/mypaint/palettes/
# copying palettes/Gnome_Palette.gpl -> /content/local/./share/mypaint/palettes/
# copying palettes/Classic_4.gpl -> /content/local/./share/mypaint/palettes/
# copying palettes/Cool_Colors.gpl -> /content/local/./share/mypaint/palettes/
# copying palettes/Zenburn.gpl -> /content/local/./share/mypaint/palettes/
# copying palettes/Visibone_2.gpl -> /content/local/./share/mypaint/palettes/
# creating /content/local/share/mypaint/pixmaps
# copying pixmaps/cursor_forbidden_everywhere.png -> /content/local/./share/mypaint/pixmaps/
# copying pixmaps/cursor_remove.png -> /content/local/./share/mypaint/pixmaps/
# copying pixmaps/cursor_move_n_s.png -> /content/local/./share/mypaint/pixmaps/
# copying pixmaps/cursor_color_picker.png -> /content/local/./share/mypaint/pixmaps/
# copying pixmaps/layers.png -> /content/local/./share/mypaint/pixmaps/
# copying pixmaps/cursor_crosshair_precise_open.png -> /content/local/./share/mypaint/pixmaps/
# copying pixmaps/mypaint_logo.png -> /content/local/./share/mypaint/pixmaps/
# copying pixmaps/cursor_color_picker_c.png -> /content/local/./share/mypaint/pixmaps/
# copying pixmaps/cursor_color_picker_h.png -> /content/local/./share/mypaint/pixmaps/
# copying pixmaps/cursor_arrow_forbidden.png -> /content/local/./share/mypaint/pixmaps/
# copying pixmaps/cursor_color_picker_y.png -> /content/local/./share/mypaint/pixmaps/
# copying pixmaps/cursor_crosshair_open.png -> /content/local/./share/mypaint/pixmaps/
# copying pixmaps/cursor_move_w_e.png -> /content/local/./share/mypaint/pixmaps/
# copying pixmaps/crosshair_closed.png -> /content/local/./share/mypaint/pixmaps/
# copying pixmaps/cursor_hand_open.png -> /content/local/./share/mypaint/pixmaps/
# copying pixmaps/cursor_arrow.png -> /content/local/./share/mypaint/pixmaps/
# copying pixmaps/cursor_move_nw_se.png -> /content/local/./share/mypaint/pixmaps/
# copying pixmaps/layer_duplicate.png -> /content/local/./share/mypaint/pixmaps/
# copying pixmaps/plus.png -> /content/local/./share/mypaint/pixmaps/
# copying pixmaps/cursor_add.png -> /content/local/./share/mypaint/pixmaps/
# copying pixmaps/cursor_hand_closed.png -> /content/local/./share/mypaint/pixmaps/
# copying pixmaps/cursor_pencil.png -> /content/local/./share/mypaint/pixmaps/
# copying pixmaps/cursor_move_ne_sw.png -> /content/local/./share/mypaint/pixmaps/
# creating /content/local/share/locale
# creating /content/local/share/locale/pl
# creating /content/local/share/locale/pl/LC_MESSAGES
# copying build/temp.linux-x86_64-3.6/locale/pl/LC_MESSAGES/mypaint.mo -> /content/local/./share/locale/pl/LC_MESSAGES
# creating /content/local/share/locale/sl
# creating /content/local/share/locale/sl/LC_MESSAGES
# copying build/temp.linux-x86_64-3.6/locale/sl/LC_MESSAGES/mypaint.mo -> /content/local/./share/locale/sl/LC_MESSAGES
# creating /content/local/share/locale/sr@cyrillic
# creating /content/local/share/locale/sr@cyrillic/LC_MESSAGES
# copying build/temp.linux-x86_64-3.6/locale/sr@cyrillic/LC_MESSAGES/mypaint.mo -> /content/local/./share/locale/sr@cyrillic/LC_MESSAGES
# creating /content/local/share/locale/hu
# creating /content/local/share/locale/hu/LC_MESSAGES
# copying build/temp.linux-x86_64-3.6/locale/hu/LC_MESSAGES/mypaint.mo -> /content/local/./share/locale/hu/LC_MESSAGES
# creating /content/local/share/locale/uk
# creating /content/local/share/locale/uk/LC_MESSAGES
# copying build/temp.linux-x86_64-3.6/locale/uk/LC_MESSAGES/mypaint.mo -> /content/local/./share/locale/uk/LC_MESSAGES
# creating /content/local/share/locale/ms
# creating /content/local/share/locale/ms/LC_MESSAGES
# copying build/temp.linux-x86_64-3.6/locale/ms/LC_MESSAGES/mypaint.mo -> /content/local/./share/locale/ms/LC_MESSAGES
# creating /content/local/share/locale/ko
# creating /content/local/share/locale/ko/LC_MESSAGES
# copying build/temp.linux-x86_64-3.6/locale/ko/LC_MESSAGES/mypaint.mo -> /content/local/./share/locale/ko/LC_MESSAGES
# creating /content/local/share/locale/en_GB
# creating /content/local/share/locale/en_GB/LC_MESSAGES
# copying build/temp.linux-x86_64-3.6/locale/en_GB/LC_MESSAGES/mypaint.mo -> /content/local/./share/locale/en_GB/LC_MESSAGES
# creating /content/local/share/locale/fi
# creating /content/local/share/locale/fi/LC_MESSAGES
# copying build/temp.linux-x86_64-3.6/locale/fi/LC_MESSAGES/mypaint.mo -> /content/local/./share/locale/fi/LC_MESSAGES
# creating /content/local/share/locale/sv
# creating /content/local/share/locale/sv/LC_MESSAGES
# copying build/temp.linux-x86_64-3.6/locale/sv/LC_MESSAGES/mypaint.mo -> /content/local/./share/locale/sv/LC_MESSAGES
# creating /content/local/share/locale/pt_BR
# creating /content/local/share/locale/pt_BR/LC_MESSAGES
# copying build/temp.linux-x86_64-3.6/locale/pt_BR/LC_MESSAGES/mypaint.mo -> /content/local/./share/locale/pt_BR/LC_MESSAGES
# creating /content/local/share/locale/el
# creating /content/local/share/locale/el/LC_MESSAGES
# copying build/temp.linux-x86_64-3.6/locale/el/LC_MESSAGES/mypaint.mo -> /content/local/./share/locale/el/LC_MESSAGES
# creating /content/local/share/locale/brx
# creating /content/local/share/locale/brx/LC_MESSAGES
# copying build/temp.linux-x86_64-3.6/locale/brx/LC_MESSAGES/mypaint.mo -> /content/local/./share/locale/brx/LC_MESSAGES
# creating /content/local/share/locale/zh_CN
# creating /content/local/share/locale/zh_CN/LC_MESSAGES
# copying build/temp.linux-x86_64-3.6/locale/zh_CN/LC_MESSAGES/mypaint.mo -> /content/local/./share/locale/zh_CN/LC_MESSAGES
# creating /content/local/share/locale/he
# creating /content/local/share/locale/he/LC_MESSAGES
# copying build/temp.linux-x86_64-3.6/locale/he/LC_MESSAGES/mypaint.mo -> /content/local/./share/locale/he/LC_MESSAGES
# creating /content/local/share/locale/da
# creating /content/local/share/locale/da/LC_MESSAGES
# copying build/temp.linux-x86_64-3.6/locale/da/LC_MESSAGES/mypaint.mo -> /content/local/./share/locale/da/LC_MESSAGES
# creating /content/local/share/locale/ru
# creating /content/local/share/locale/ru/LC_MESSAGES
# copying build/temp.linux-x86_64-3.6/locale/ru/LC_MESSAGES/mypaint.mo -> /content/local/./share/locale/ru/LC_MESSAGES
# creating /content/local/share/locale/it
# creating /content/local/share/locale/it/LC_MESSAGES
# copying build/temp.linux-x86_64-3.6/locale/it/LC_MESSAGES/mypaint.mo -> /content/local/./share/locale/it/LC_MESSAGES
# creating /content/local/share/locale/fa
# creating /content/local/share/locale/fa/LC_MESSAGES
# copying build/temp.linux-x86_64-3.6/locale/fa/LC_MESSAGES/mypaint.mo -> /content/local/./share/locale/fa/LC_MESSAGES
# creating /content/local/share/locale/tr
# creating /content/local/share/locale/tr/LC_MESSAGES
# copying build/temp.linux-x86_64-3.6/locale/tr/LC_MESSAGES/mypaint.mo -> /content/local/./share/locale/tr/LC_MESSAGES
# creating /content/local/share/locale/eo
# creating /content/local/share/locale/eo/LC_MESSAGES
# copying build/temp.linux-x86_64-3.6/locale/eo/LC_MESSAGES/mypaint.mo -> /content/local/./share/locale/eo/LC_MESSAGES
# creating /content/local/share/locale/en_CA
# creating /content/local/share/locale/en_CA/LC_MESSAGES
# copying build/temp.linux-x86_64-3.6/locale/en_CA/LC_MESSAGES/mypaint.mo -> /content/local/./share/locale/en_CA/LC_MESSAGES
# creating /content/local/share/locale/nn_NO
# creating /content/local/share/locale/nn_NO/LC_MESSAGES
# copying build/temp.linux-x86_64-3.6/locale/nn_NO/LC_MESSAGES/mypaint.mo -> /content/local/./share/locale/nn_NO/LC_MESSAGES
# creating /content/local/share/locale/fr
# creating /content/local/share/locale/fr/LC_MESSAGES
# copying build/temp.linux-x86_64-3.6/locale/fr/LC_MESSAGES/mypaint.mo -> /content/local/./share/locale/fr/LC_MESSAGES
# creating /content/local/share/locale/is
# creating /content/local/share/locale/is/LC_MESSAGES
# copying build/temp.linux-x86_64-3.6/locale/is/LC_MESSAGES/mypaint.mo -> /content/local/./share/locale/is/LC_MESSAGES
# creating /content/local/share/locale/ro
# creating /content/local/share/locale/ro/LC_MESSAGES
# copying build/temp.linux-x86_64-3.6/locale/ro/LC_MESSAGES/mypaint.mo -> /content/local/./share/locale/ro/LC_MESSAGES
# creating /content/local/share/locale/cs
# creating /content/local/share/locale/cs/LC_MESSAGES
# copying build/temp.linux-x86_64-3.6/locale/cs/LC_MESSAGES/mypaint.mo -> /content/local/./share/locale/cs/LC_MESSAGES
# creating /content/local/share/locale/nb
# creating /content/local/share/locale/nb/LC_MESSAGES
# copying build/temp.linux-x86_64-3.6/locale/nb/LC_MESSAGES/mypaint.mo -> /content/local/./share/locale/nb/LC_MESSAGES
# creating /content/local/share/locale/es
# creating /content/local/share/locale/es/LC_MESSAGES
# copying build/temp.linux-x86_64-3.6/locale/es/LC_MESSAGES/mypaint.mo -> /content/local/./share/locale/es/LC_MESSAGES
# creating /content/local/share/locale/ja
# creating /content/local/share/locale/ja/LC_MESSAGES
# copying build/temp.linux-x86_64-3.6/locale/ja/LC_MESSAGES/mypaint.mo -> /content/local/./share/locale/ja/LC_MESSAGES
# creating /content/local/share/locale/de
# creating /content/local/share/locale/de/LC_MESSAGES
# copying build/temp.linux-x86_64-3.6/locale/de/LC_MESSAGES/mypaint.mo -> /content/local/./share/locale/de/LC_MESSAGES
# creating /content/local/share/locale/id
# creating /content/local/share/locale/id/LC_MESSAGES
# copying build/temp.linux-x86_64-3.6/locale/id/LC_MESSAGES/mypaint.mo -> /content/local/./share/locale/id/LC_MESSAGES
# creating /content/local/share/locale/ca
# creating /content/local/share/locale/ca/LC_MESSAGES
# copying build/temp.linux-x86_64-3.6/locale/ca/LC_MESSAGES/mypaint.mo -> /content/local/./share/locale/ca/LC_MESSAGES
# creating /content/local/share/locale/zh_TW
# creating /content/local/share/locale/zh_TW/LC_MESSAGES
# copying build/temp.linux-x86_64-3.6/locale/zh_TW/LC_MESSAGES/mypaint.mo -> /content/local/./share/locale/zh_TW/LC_MESSAGES
# creating /content/local/share/locale/ckb
# creating /content/local/share/locale/ckb/LC_MESSAGES
# copying build/temp.linux-x86_64-3.6/locale/ckb/LC_MESSAGES/mypaint.mo -> /content/local/./share/locale/ckb/LC_MESSAGES
# creating /content/local/share/locale/kab
# creating /content/local/share/locale/kab/LC_MESSAGES
# copying build/temp.linux-x86_64-3.6/locale/kab/LC_MESSAGES/mypaint.mo -> /content/local/./share/locale/kab/LC_MESSAGES
# creating /content/local/share/locale/sk
# creating /content/local/share/locale/sk/LC_MESSAGES
# copying build/temp.linux-x86_64-3.6/locale/sk/LC_MESSAGES/mypaint.mo -> /content/local/./share/locale/sk/LC_MESSAGES
# running install_egg_info
# running egg_info
# creating MyPaint.egg-info
# writing MyPaint.egg-info/PKG-INFO
# writing dependency_links to MyPaint.egg-info/dependency_links.txt
# writing top-level names to MyPaint.egg-info/top_level.txt
# writing manifest file 'MyPaint.egg-info/SOURCES.txt'
# reading manifest file 'MyPaint.egg-info/SOURCES.txt'
# writing manifest file 'MyPaint.egg-info/SOURCES.txt'
# Copying MyPaint.egg-info to /content/local/./lib/mypaint/MyPaint-2.0.0a0-py3.6.egg-info
# running install_scripts
# creating /content/local/bin
# installing build/scripts-3.6/mypaint.py as mypaint
# changing mode of /content/local/./bin/mypaint to 755
# installing build/scripts-3.6/mypaint-ora-thumbnailer.py as mypaint-ora-thumbnailer
# changing mode of /content/local/./bin/mypaint-ora-thumbnailer to 755
# writing list of installed files to '/content/local/./lib/mypaint/managed_files.txt'

# %%
# !pip install kornia
# Out:
# Collecting kornia
#   Downloading https://files.pythonhosted.org/packages/e7/05/4adc0140932d37ab1ff02f3a88c3362d5d31b999936bb3af651f641e1295/kornia-0.1.4.post2-py2.py3-none-any.whl (114kB)
#      |████████████████████████████████| 122kB 4.9MB/s
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.6/dist-packages (from kornia) (1.3.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torch>=1.0.0->kornia) (1.17.4)
# Installing collected packages: kornia
# Successfully installed kornia-0.1.4.post2

# %%
#!rm -r neural-painters-pytorch
#!rm -r neural_painters
# !git clone https://github.com/reiinakano/neural-painters-pytorch.git
# !cp -r neural-painters-pytorch/neural_painters neural_painters
# Out:
# Cloning into 'neural-painters-pytorch'...
# remote: Enumerating objects: 290, done.
# remote: Counting objects: 100% (290/290), done.
# remote: Compressing objects: 100% (184/184), done.
# remote: Total 290 (delta 180), reused 201 (delta 103), pack-reused 0
# Receiving objects: 100% (290/290), 10.36 MiB | 19.14 MiB/s, done.
# Resolving deltas: 100% (180/180), done.

# %% [markdown]
# # imports

# %%
# %tensorflow_version 1.x
# %load_ext tensorboard
import sys
sys.path.append('/content/local/lib/mypaint')  # MyPaint is a local installation

import torch
import torchvision.utils as utils

import numpy as np
import matplotlib.pyplot as plt

from IPython.display import display
import moviepy.editor as mpy

from neural_painters.vae_painter import VAENeuralPainter, train_vae_neural_painter
from neural_painters.data import FullActionStrokeDataLoader
from neural_painters.viz import validate_neural_painter, neural_painter_stroke_animation
from neural_painters.mypaint_env import ColorEnv, PaintMode
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
SCREEN_SIZE = 64
Z_SIZE = 64
KL_TOLERANCE = 0.5
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# all 0 to 1
ACTIONS_TO_IDX = {
    'pressure': 0,
    'size': 1,
    'control_x': 2,
    'control_y': 3,
    'end_x': 4,
    'end_y': 5,
    'color_r': 6,
    'color_g': 7,
    'color_b': 8,
    'start_x': 9,
    'start_y': 10,
    'entry_pressure': 11,
}

# %%
def imshow(img):
  npimg = img.numpy()
  plt.imshow(np.transpose(npimg, (1, 2, 0)))
  plt.show()

loader = FullActionStrokeDataLoader('data', 64, False)
"""
for batch in loader:
  print(batch['stroke'].shape, batch['action'].shape)
  print(batch['stroke'].mean(), batch['action'].mean())
  imshow(utils.make_grid(batch['stroke']))
  break
"""
# Out:
# "\nfor batch in loader:\n  print(batch['stroke'].shape, batch['action'].shape)\n  print(batch['stroke'].mean(), batch['action'].mean())\n  imshow(utils.make_grid(batch['stroke']))\n  break\n"

# %% [markdown]
# # Train

# %%
# Optional: Load your checkpoints from Drive
#!cp -r /drive/My\ Drive/neural-painters-pytorch/vae_logdir logdir
#!cp -r /drive/My\ Drive/neural-painters-pytorch/vae_train_checkpoints vae_train_checkpoints

# %%
# Run tensorboard i.e. greatest thing since sliced bread
# %tensorboard --logdir logdir

# %%
train_vae_neural_painter(Z_SIZE, 
                         len(ACTIONS_TO_IDX),
                         batch_size=64, 
                         kl_tolerance=KL_TOLERANCE, 
                         device=device, 
                         data_dir='data')
# Out:
# Loaded from vae_train_checkpoints/vae_neural_painter_latest.tar. Batch 175000
# Loading data/episodes_37.npz
# train batch 176000	Loss: 53.406101	KLD: 33.380692	RLOSS: 20.025410
# Loading data/episodes_0.npz
# train batch 178000	Loss: 57.230721	KLD: 33.379387	RLOSS: 23.851336
# Loading data/episodes_62.npz
# Loading data/episodes_3.npz
# train batch 180000	Loss: 53.386776	KLD: 33.835625	RLOSS: 19.551151
# Loading data/episodes_36.npz
# train batch 182000	Loss: 59.753822	KLD: 34.206661	RLOSS: 25.547159
# Loading data/episodes_34.npz
# train batch 184000	Loss: 57.101883	KLD: 33.563057	RLOSS: 23.538828
# Loading data/episodes_69.npz
# Loading data/episodes_38.npz
# train batch 186000	Loss: 54.618847	KLD: 33.198097	RLOSS: 21.420750
# Loading data/episodes_55.npz
# train batch 188000	Loss: 49.215820	KLD: 33.392948	RLOSS: 15.822873
# Loading data/episodes_58.npz
# train batch 190000	Loss: 55.659042	KLD: 33.299858	RLOSS: 22.359182
# Loading data/episodes_13.npz
# train batch 192000	Loss: 57.768002	KLD: 33.729385	RLOSS: 24.038616
# Loading data/episodes_31.npz
# Loading data/episodes_67.npz
# train batch 194000	Loss: 54.951080	KLD: 33.348579	RLOSS: 21.602501
# Loading data/episodes_32.npz
# train batch 196000	Loss: 51.911331	KLD: 32.967834	RLOSS: 18.943495
# Loading data/episodes_61.npz
# train batch 198000	Loss: 55.525162	KLD: 33.326977	RLOSS: 22.198185
# Loading data/episodes_68.npz
# train batch 200000	Loss: 52.018448	KLD: 32.818741	RLOSS: 19.199707
# saved vae_neural_painter_200000.tar
# Loading data/episodes_25.npz
# Loading data/episodes_11.npz
# train batch 202000	Loss: 53.551926	KLD: 33.157104	RLOSS: 20.394821
# Loading data/episodes_27.npz
# train batch 204000	Loss: 56.612930	KLD: 33.142181	RLOSS: 23.470751
# Loading data/episodes_52.npz
# train batch 206000	Loss: 50.608421	KLD: 33.177376	RLOSS: 17.431047
# Loading data/episodes_2.npz
# Loading data/episodes_51.npz
# train batch 208000	Loss: 56.962170	KLD: 33.905289	RLOSS: 23.056881
# Loading data/episodes_46.npz
# train batch 210000	Loss: 58.432373	KLD: 34.283669	RLOSS: 24.148705
# Loading data/episodes_71.npz
# train batch 212000	Loss: 54.353367	KLD: 33.451294	RLOSS: 20.902073
# Loading data/episodes_63.npz
# train batch 214000	Loss: 56.541153	KLD: 33.510422	RLOSS: 23.030731
# Loading data/episodes_59.npz
# Loading data/episodes_50.npz
# train batch 216000	Loss: 58.284081	KLD: 33.661858	RLOSS: 24.622223
# Loading data/episodes_28.npz
# train batch 218000	Loss: 55.715664	KLD: 33.373871	RLOSS: 22.341793
# Loading data/episodes_74.npz
# train batch 220000	Loss: 53.677547	KLD: 33.327560	RLOSS: 20.349987
# Loading data/episodes_8.npz
# Loading data/episodes_54.npz
# train batch 222000	Loss: 56.746155	KLD: 34.436302	RLOSS: 22.309855
# Loading data/episodes_18.npz
# train batch 224000	Loss: 56.380352	KLD: 33.590683	RLOSS: 22.789669
# saved vae_neural_painter_225000.tar
# Loading data/episodes_42.npz
# train batch 226000	Loss: 51.548885	KLD: 32.886230	RLOSS: 18.662655
# Loading data/episodes_53.npz
# train batch 228000	Loss: 56.047485	KLD: 33.585457	RLOSS: 22.462029
# Loading data/episodes_48.npz
# Loading data/episodes_41.npz
# train batch 230000	Loss: 54.374928	KLD: 33.050575	RLOSS: 21.324352
# Loading data/episodes_35.npz
# train batch 232000	Loss: 57.569557	KLD: 33.873260	RLOSS: 23.696295
# Loading data/episodes_6.npz
# train batch 234000	Loss: 56.524521	KLD: 33.457134	RLOSS: 23.067387
# Loading data/episodes_77.npz
# Loading data/episodes_4.npz
# train batch 236000	Loss: 54.919067	KLD: 33.109703	RLOSS: 21.809364
# Loading data/episodes_5.npz
# train batch 238000	Loss: 54.020824	KLD: 33.404476	RLOSS: 20.616348
# Loading data/episodes_45.npz
# train batch 240000	Loss: 52.268654	KLD: 32.945984	RLOSS: 19.322672
# Loading data/episodes_60.npz
# train batch 242000	Loss: 54.404518	KLD: 33.524460	RLOSS: 20.880058
# Loading data/episodes_66.npz
# Loading data/episodes_7.npz
# train batch 244000	Loss: 57.271938	KLD: 33.615463	RLOSS: 23.656475
# Loading data/episodes_64.npz
# train batch 246000	Loss: 57.836620	KLD: 34.255627	RLOSS: 23.580994
# Loading data/episodes_40.npz
# train batch 248000	Loss: 53.078110	KLD: 33.240734	RLOSS: 19.837374
# Loading data/episodes_33.npz
# train batch 250000	Loss: 55.885677	KLD: 33.630939	RLOSS: 22.254738
# saved vae_neural_painter_250000.tar
# Loading data/episodes_75.npz
# Loading data/episodes_24.npz
# train batch 252000	Loss: 53.380333	KLD: 33.776810	RLOSS: 19.603523
# Loading data/episodes_29.npz
# train batch 254000	Loss: 57.689491	KLD: 33.567474	RLOSS: 24.122017
# Loading data/episodes_14.npz
# train batch 256000	Loss: 54.170235	KLD: 33.401821	RLOSS: 20.768414
# Loading data/episodes_15.npz
# Loading data/episodes_10.npz
# train batch 258000	Loss: 53.620575	KLD: 33.329407	RLOSS: 20.291168
# Loading data/episodes_76.npz
# train batch 260000	Loss: 55.141224	KLD: 33.522293	RLOSS: 21.618931
# Loading data/episodes_21.npz
# train batch 262000	Loss: 51.345039	KLD: 33.040470	RLOSS: 18.304569
# Loading data/episodes_23.npz
# train batch 264000	Loss: 50.330635	KLD: 32.899151	RLOSS: 17.431482
# Loading data/episodes_44.npz
# Loading data/episodes_65.npz
# train batch 266000	Loss: 53.669327	KLD: 33.218441	RLOSS: 20.450884
# Loading data/episodes_16.npz
# train batch 268000	Loss: 57.854279	KLD: 33.640785	RLOSS: 24.213493
# Loading data/episodes_19.npz
# train batch 270000	Loss: 55.683571	KLD: 33.649609	RLOSS: 22.033960
# Loading data/episodes_22.npz
# Loading data/episodes_9.npz
# train batch 272000	Loss: 58.515823	KLD: 33.566628	RLOSS: 24.949196
# Loading data/episodes_26.npz
# train batch 274000	Loss: 57.061901	KLD: 33.094467	RLOSS: 23.967434
# saved vae_neural_painter_275000.tar
# Loading data/episodes_39.npz
# train batch 276000	Loss: 49.591740	KLD: 32.771133	RLOSS: 16.820606
# Loading data/episodes_43.npz
# train batch 278000	Loss: 55.365231	KLD: 33.692177	RLOSS: 21.673054
# Loading data/episodes_12.npz
# Loading data/episodes_30.npz
# train batch 280000	Loss: 50.498123	KLD: 33.107479	RLOSS: 17.390644
# Loading data/episodes_73.npz
# train batch 282000	Loss: 57.957726	KLD: 33.673698	RLOSS: 24.284025
# Loading data/episodes_1.npz
# train batch 284000	Loss: 52.174973	KLD: 33.211113	RLOSS: 18.963861
# Loading data/episodes_49.npz
# Loading data/episodes_47.npz
# train batch 286000	Loss: 54.096840	KLD: 33.181526	RLOSS: 20.915312
# Loading data/episodes_72.npz
# train batch 288000	Loss: 56.953758	KLD: 33.410957	RLOSS: 23.542801
# Loading data/episodes_70.npz
# train batch 290000	Loss: 53.379974	KLD: 33.513283	RLOSS: 19.866693
# Loading data/episodes_57.npz
# train batch 292000	Loss: 58.107189	KLD: 33.380569	RLOSS: 24.726620
# Loading data/episodes_56.npz
# Loading data/episodes_20.npz
# train batch 294000	Loss: 57.018673	KLD: 33.174526	RLOSS: 23.844147
# Loading data/episodes_17.npz
# train batch 296000	Loss: 52.018394	KLD: 33.007393	RLOSS: 19.011002
# Loading data/episodes_44.npz
# train batch 298000	Loss: 52.701218	KLD: 32.859974	RLOSS: 19.841244
# Loading data/episodes_29.npz
# train batch 300000	Loss: 5.763324	MU_MSE: 0.594693	LV_MSE: 5.168631
# saved vae_neural_painter_300000.tar
# Loading data/episodes_74.npz
# Loading data/episodes_71.npz
# train batch 302000	Loss: 0.119726	MU_MSE: 0.070500	LV_MSE: 0.049226
# Loading data/episodes_68.npz
# train batch 304000	Loss: 0.106931	MU_MSE: 0.060232	LV_MSE: 0.046699
# Loading data/episodes_34.npz
# train batch 306000	Loss: 0.095873	MU_MSE: 0.056596	LV_MSE: 0.039277
# Loading data/episodes_66.npz
# Loading data/episodes_11.npz
# train batch 308000	Loss: 0.099497	MU_MSE: 0.054158	LV_MSE: 0.045339
# Loading data/episodes_63.npz
# train batch 310000	Loss: 0.082613	MU_MSE: 0.051624	LV_MSE: 0.030989
# Loading data/episodes_52.npz
# train batch 312000	Loss: 0.109161	MU_MSE: 0.061644	LV_MSE: 0.047517
# Loading data/episodes_16.npz
# train batch 314000	Loss: 0.089386	MU_MSE: 0.048734	LV_MSE: 0.040652
# Loading data/episodes_40.npz
# Loading data/episodes_17.npz
# train batch 316000	Loss: 0.089957	MU_MSE: 0.052704	LV_MSE: 0.037254
# Loading data/episodes_54.npz
# train batch 318000	Loss: 0.082437	MU_MSE: 0.049394	LV_MSE: 0.033042
# Loading data/episodes_60.npz
# train batch 320000	Loss: 0.085187	MU_MSE: 0.052250	LV_MSE: 0.032937
# Loading data/episodes_27.npz
# Loading data/episodes_72.npz
# train batch 322000	Loss: 0.073066	MU_MSE: 0.042525	LV_MSE: 0.030541
# Loading data/episodes_13.npz
# train batch 324000	Loss: 0.084232	MU_MSE: 0.049754	LV_MSE: 0.034479
# saved vae_neural_painter_325000.tar
# Loading data/episodes_65.npz
# train batch 326000	Loss: 0.085436	MU_MSE: 0.049403	LV_MSE: 0.036033
# Loading data/episodes_57.npz
# train batch 328000	Loss: 0.076607	MU_MSE: 0.049012	LV_MSE: 0.027595
# Loading data/episodes_70.npz
# Loading data/episodes_15.npz
# train batch 330000	Loss: 0.076018	MU_MSE: 0.046458	LV_MSE: 0.029560
# Loading data/episodes_76.npz
# train batch 332000	Loss: 0.060990	MU_MSE: 0.039651	LV_MSE: 0.021339
# Loading data/episodes_5.npz
# train batch 334000	Loss: 0.070394	MU_MSE: 0.041261	LV_MSE: 0.029133
# Loading data/episodes_35.npz
# Loading data/episodes_26.npz
# train batch 336000	Loss: 0.071730	MU_MSE: 0.044562	LV_MSE: 0.027168
# Loading data/episodes_64.npz
# train batch 338000	Loss: 0.078404	MU_MSE: 0.049771	LV_MSE: 0.028633
# Loading data/episodes_47.npz
# train batch 340000	Loss: 0.067870	MU_MSE: 0.040360	LV_MSE: 0.027510
# Loading data/episodes_67.npz
# train batch 342000	Loss: 0.066981	MU_MSE: 0.038551	LV_MSE: 0.028429
# Loading data/episodes_2.npz
# Loading data/episodes_45.npz
# train batch 344000	Loss: 0.063735	MU_MSE: 0.038427	LV_MSE: 0.025308
# Loading data/episodes_58.npz
# train batch 346000	Loss: 0.073564	MU_MSE: 0.046570	LV_MSE: 0.026994
# Loading data/episodes_61.npz
# train batch 348000	Loss: 0.083686	MU_MSE: 0.053615	LV_MSE: 0.030071
# Loading data/episodes_7.npz
# train batch 350000	Loss: 0.068731	MU_MSE: 0.042369	LV_MSE: 0.026361
# saved vae_neural_painter_350000.tar
# Loading data/episodes_25.npz
# Loading data/episodes_12.npz
# train batch 352000	Loss: 0.065871	MU_MSE: 0.037510	LV_MSE: 0.028361
# Loading data/episodes_9.npz
# train batch 354000	Loss: 0.067618	MU_MSE: 0.040408	LV_MSE: 0.027210
# Loading data/episodes_38.npz
# train batch 356000	Loss: 0.075916	MU_MSE: 0.042827	LV_MSE: 0.033089
# Loading data/episodes_43.npz
# Loading data/episodes_36.npz
# train batch 358000	Loss: 0.066742	MU_MSE: 0.041970	LV_MSE: 0.024773
# Loading data/episodes_75.npz
# train batch 360000	Loss: 0.076804	MU_MSE: 0.047063	LV_MSE: 0.029741
# Loading data/episodes_18.npz
# train batch 362000	Loss: 0.069730	MU_MSE: 0.042182	LV_MSE: 0.027548
# Loading data/episodes_56.npz
# train batch 364000	Loss: 0.068429	MU_MSE: 0.042144	LV_MSE: 0.026286
# Loading data/episodes_21.npz
# Loading data/episodes_49.npz
# train batch 366000	Loss: 0.066841	MU_MSE: 0.041014	LV_MSE: 0.025827
# Loading data/episodes_10.npz
# train batch 368000	Loss: 0.067454	MU_MSE: 0.042363	LV_MSE: 0.025091
# Loading data/episodes_39.npz
# train batch 370000	Loss: 0.077529	MU_MSE: 0.046544	LV_MSE: 0.030985
# Loading data/episodes_37.npz
# Loading data/episodes_62.npz
# train batch 372000	Loss: 0.065867	MU_MSE: 0.041790	LV_MSE: 0.024077
# Loading data/episodes_30.npz
# train batch 374000	Loss: 0.069187	MU_MSE: 0.042872	LV_MSE: 0.026315
# saved vae_neural_painter_375000.tar
# Loading data/episodes_69.npz
# train batch 376000	Loss: 0.062700	MU_MSE: 0.038754	LV_MSE: 0.023946
# Loading data/episodes_8.npz
# train batch 378000	Loss: 0.071607	MU_MSE: 0.041104	LV_MSE: 0.030503
# Loading data/episodes_4.npz
# Loading data/episodes_55.npz
# train batch 380000	Loss: 0.075767	MU_MSE: 0.044162	LV_MSE: 0.031605
# Loading data/episodes_59.npz
# train batch 382000	Loss: 0.083630	MU_MSE: 0.048664	LV_MSE: 0.034967
# Loading data/episodes_33.npz
# train batch 384000	Loss: 0.070691	MU_MSE: 0.040907	LV_MSE: 0.029783
# Loading data/episodes_22.npz
# train batch 386000	Loss: 0.074602	MU_MSE: 0.042264	LV_MSE: 0.032338
# Loading data/episodes_0.npz
# Loading data/episodes_14.npz
# train batch 388000	Loss: 0.083511	MU_MSE: 0.044586	LV_MSE: 0.038926
# Loading data/episodes_20.npz
# train batch 390000	Loss: 0.065757	MU_MSE: 0.037689	LV_MSE: 0.028067
# Loading data/episodes_46.npz
# train batch 392000	Loss: 0.066776	MU_MSE: 0.044923	LV_MSE: 0.021853
# Loading data/episodes_53.npz
# Loading data/episodes_28.npz
# train batch 394000	Loss: 0.093185	MU_MSE: 0.053847	LV_MSE: 0.039337
# Loading data/episodes_73.npz
# train batch 396000	Loss: 0.083768	MU_MSE: 0.044603	LV_MSE: 0.039165
# Loading data/episodes_41.npz
# train batch 398000	Loss: 0.059470	MU_MSE: 0.034607	LV_MSE: 0.024863
# Loading data/episodes_48.npz
# train batch 400000	Loss: 0.079865	MU_MSE: 0.045495	LV_MSE: 0.034369
# saved vae_neural_painter_400000.tar
# Loading data/episodes_77.npz
# Loading data/episodes_19.npz
# train batch 402000	Loss: 0.070499	MU_MSE: 0.043350	LV_MSE: 0.027149
# Loading data/episodes_1.npz
# train batch 404000	Loss: 0.062227	MU_MSE: 0.040925	LV_MSE: 0.021302
# Loading data/episodes_50.npz
# train batch 406000	Loss: 0.064506	MU_MSE: 0.037299	LV_MSE: 0.027207
# Loading data/episodes_31.npz
# Loading data/episodes_23.npz
# train batch 408000	Loss: 0.068915	MU_MSE: 0.043672	LV_MSE: 0.025243
# Loading data/episodes_32.npz
# train batch 410000	Loss: 0.077640	MU_MSE: 0.047500	LV_MSE: 0.030139
# Loading data/episodes_24.npz
# train batch 412000	Loss: 0.086203	MU_MSE: 0.046855	LV_MSE: 0.039348
# Loading data/episodes_42.npz
# train batch 414000	Loss: 0.061068	MU_MSE: 0.040199	LV_MSE: 0.020868
# Loading data/episodes_6.npz
# Loading data/episodes_51.npz
# train batch 416000	Loss: 0.066378	MU_MSE: 0.040772	LV_MSE: 0.025605
# Loading data/episodes_3.npz
# train batch 418000	Loss: 0.062017	MU_MSE: 0.038940	LV_MSE: 0.023077
# Loading data/episodes_58.npz
# train batch 420000	Loss: 0.068308	MU_MSE: 0.037849	LV_MSE: 0.030459
# Loading data/episodes_49.npz
# Loading data/episodes_32.npz
# train batch 422000	Loss: 0.071524	MU_MSE: 0.045751	LV_MSE: 0.025773
# Loading data/episodes_39.npz
# train batch 424000	Loss: 0.063626	MU_MSE: 0.037847	LV_MSE: 0.025779
# saved vae_neural_painter_425000.tar
# Loading data/episodes_60.npz
# train batch 426000	Loss: 0.061388	MU_MSE: 0.036827	LV_MSE: 0.024561
# Loading data/episodes_13.npz
# train batch 428000	Loss: 0.078029	MU_MSE: 0.047476	LV_MSE: 0.030554
# Loading data/episodes_46.npz
# Loading data/episodes_48.npz
# train batch 430000	Loss: 0.067949	MU_MSE: 0.039603	LV_MSE: 0.028346
# Loading data/episodes_31.npz
# train batch 432000	Loss: 0.060982	MU_MSE: 0.036602	LV_MSE: 0.024380
# Loading data/episodes_19.npz
# train batch 434000	Loss: 0.074949	MU_MSE: 0.043645	LV_MSE: 0.031304
# Loading data/episodes_9.npz
# train batch 436000	Loss: 0.071536	MU_MSE: 0.045221	LV_MSE: 0.026315
# Loading data/episodes_11.npz
# Loading data/episodes_72.npz
# train batch 438000	Loss: 0.078394	MU_MSE: 0.047719	LV_MSE: 0.030675
# Loading data/episodes_21.npz
# train batch 440000	Loss: 0.075193	MU_MSE: 0.042754	LV_MSE: 0.032439
# Loading data/episodes_35.npz
# train batch 442000	Loss: 0.071669	MU_MSE: 0.042476	LV_MSE: 0.029193
# Loading data/episodes_6.npz
# Loading data/episodes_56.npz
# train batch 444000	Loss: 0.071013	MU_MSE: 0.043385	LV_MSE: 0.027628
# Loading data/episodes_51.npz
# train batch 446000	Loss: 0.072707	MU_MSE: 0.043930	LV_MSE: 0.028777
# Loading data/episodes_53.npz
# train batch 448000	Loss: 0.074381	MU_MSE: 0.037340	LV_MSE: 0.037041
# Loading data/episodes_54.npz
# train batch 450000	Loss: 0.089362	MU_MSE: 0.053998	LV_MSE: 0.035364
# saved vae_neural_painter_450000.tar
# Loading data/episodes_77.npz
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-87f696bbb924> in <module>()
#       4                          kl_tolerance=KL_TOLERANCE,
#       5                          device=device,
# ----> 6                          data_dir='data')
#
# /content/neural_painters/vae_painter.py in train_vae_neural_painter(z_size, action_size, batch_size, kl_tolerance, device, data_dir, vae_train_steps, save_every_n_steps, log_every_n_steps, tensorboard_every_n_steps, tensorboard_log_dir, save_dir, save_name)
#     279         loss = mu_mse + log_var_mse
#     280         loss.backward()
# --> 281         optimizer2.step()
#     282
#     283         writer.add_scalar('loss2', loss, batch_idx)
#
# /usr/local/lib/python3.6/dist-packages/torch/optim/adam.py in step(self, closure)
#      94                 # Decay the first and second moment running average coefficient
#      95                 exp_avg.mul_(beta1).add_(1 - beta1, grad)
# ---> 96                 exp_avg_sq.mul_(beta2).addcmul_(1 - beta2, grad, grad)
#      97                 if amsgrad:
#      98                     # Maintains the maximum of all 2nd moment running avg. till now
#
# KeyboardInterrupt:

# %%
# Optional: Save logdir in Drive
#!mkdir /drive/My\ Drive/neural-painters-pytorch/vae_logdir
#!cp logdir/* /drive/My\ Drive/neural-painters-pytorch/vae_logdir/

# %%
# Optional: Save checkpoints in Drive
#!mkdir /drive/My\ Drive/neural-painters-pytorch/vae_train_checkpoints
#!cp vae_train_checkpoints/* /drive/My\ Drive/neural-painters-pytorch/vae_train_checkpoints/

# %% [markdown]
# # Test trained model

# %%
vae_np = VAENeuralPainter(len(ACTIONS_TO_IDX), Z_SIZE, stochastic=False).eval()
checkpoints_to_test = ['vae_train_checkpoints/vae_neural_painter_350000.tar',
                       'vae_train_checkpoints/vae_neural_painter_400000.tar',
                       'vae_train_checkpoints/vae_neural_painter_450000.tar',]

for idx, batch in enumerate(loader):
  strokes = batch['stroke'].float()[:8]
  actions = batch['action'].float()[:8]
  validate_neural_painter(strokes, actions, vae_np, checkpoints_to_test)
  break
# Out:
# Loading data/episodes_5.npz
# Loaded from vae_train_checkpoints/vae_neural_painter_350000.tar. Batch 350000
# Loaded from vae_train_checkpoints/vae_neural_painter_400000.tar. Batch 400000
# Loaded from vae_train_checkpoints/vae_neural_painter_450000.tar. Batch 450000

# %%
neural_painter_stroke_animation(
    lambda: VAENeuralPainter(len(ACTIONS_TO_IDX), Z_SIZE, stochastic=True).eval(), 
    len(ACTIONS_TO_IDX),
    checkpoints_to_test, 'tmp.mp4', real_env=ColorEnv(paint_mode=PaintMode.STROKES_ONLY))
display(mpy.ipython_display('tmp.mp4', height=400))
# Out:
# Loaded from vae_train_checkpoints/vae_neural_painter_350000.tar. Batch 350000
# Loaded from vae_train_checkpoints/vae_neural_painter_400000.tar. Batch 400000
# Loaded from vae_train_checkpoints/vae_neural_painter_450000.tar. Batch 450000
# [MoviePy] >>>> Building video tmp.mp4
# [MoviePy] Writing video tmp.mp4
# 100%|█████████▉| 300/301 [00:11<00:00, 25.62it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: tmp.mp4
# written to tmp.mp4
# <div align=middle><video height='400'src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>
